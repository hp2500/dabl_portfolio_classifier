# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import scipy as sp
import seaborn as sb

# %%
benchmark_summary = pd.read_csv('/Users/hp2500/Google Drive/STUDY/Columbia/Research/dabl_final/benchmark/result_summary.csv')

# %%
benchmark_all = pd.read_csv('/Users/hp2500/Google Drive/STUDY/Columbia/Research/dabl_final/benchmark/all_results.csv')

# %%
benchmark_summary
# Out:
#           type                                    task  autosklearn  \
# 0       binary                                   adult     0.929528
# 1       binary                  amazon_employee_access     0.855949
# 2       binary                              apsfailure     0.991173
# 3       binary                              australian     0.935352
# 4       binary                          bank-marketing     0.937332
# 5       binary                       blood-transfusion     0.757376
# 6       binary                               christine     0.829747
# 7       binary                                credit-g     0.782619
# 8       binary                              guiellermo     0.901298
# 9       binary                                   higgs     0.793323
# 10      binary                                 jasmine     0.883949
# 11      binary                                     kc1  0.84251 (1)
# 12      binary                      kddcup09_appetency      0.83399
# ...

# %%
benchmark_all
# Out:
#            acc  auc  duration  fold          framework                   id  \
# 0     0.550725  0.5       0.0     0  constantpredictor  openml.org/t/146818
# 1     0.550725  0.5       0.0     1  constantpredictor  openml.org/t/146818
# 2     0.550725  0.5       0.0     2  constantpredictor  openml.org/t/146818
# 3     0.550725  0.5       0.0     3  constantpredictor  openml.org/t/146818
# 4     0.550725  0.5       0.0     4  constantpredictor  openml.org/t/146818
# 5     0.550725  0.5       0.0     5  constantpredictor  openml.org/t/146818
# 6     0.550725  0.5       0.0     6  constantpredictor  openml.org/t/146818
# 7     0.565217  0.5       0.0     7  constantpredictor  openml.org/t/146818
# 8     0.565217  0.5       0.0     8  constantpredictor  openml.org/t/146818
# 9     0.565217  0.5       0.0     9  constantpredictor  openml.org/t/146818
# 10    0.760000  0.5       0.0     0  constantpredictor   openml.org/t/10101
# ...

# %%
benchmark.groupby(['task']).size()
# Out:
# task
# Australian           47
# blood-transfusion    50
# car                  50
# christine            50
# cnae-9               49
# credit-g             50
# dilbert              50
# fabert               49
# jasmine              50
# kc1                  50
# kr-vs-kp             50
# mfeat-factors        49
# phoneme              50
# segment              50
# sylvine              50
# vehicle              50
# dtype: int64
