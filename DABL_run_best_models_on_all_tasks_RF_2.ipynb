# %% [markdown]
# # Best runs on all tasks

# %% [markdown]
# ## Import modules

# %%
# import modules
import importlib
import utils.functions_analyze_runs
importlib.reload(utils.functions_analyze_runs)
importlib.reload(sklearn)


import openml
from openml import tasks, flows, runs
import sklearn
from sklearn import feature_selection
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import pprint
from collections import OrderedDict, Counter
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
import re
import random
import numpy as np
from datetime import datetime
import sys
import matplotlib.pyplot as plt
import json
from itertools import combinations
import signal



from utils.functions_analyze_runs import get_run_info_rf, get_run_info

# set api key
openml.config.apikey = open('.key', 'r').readline().strip('\n')

# %%
# get all supervised classification tasks
tasks_all = openml.tasks.list_tasks(task_type_id=1, output_format='dataframe', tag = 'OpenML-CC18')
# drop problematic tasks
tasks_all = tasks_all.drop([3573, 146825, 167121, 167124])`

# %% [markdown]
# ## Get OpenML runs for RF flows

# %%
# get SVC evals
good_flows = [5804, 8365, 5909, 8918, 6969, 8315, 8351]
evals = openml.evaluations.list_evaluations('area_under_roc_curve',
                                            flow= good_flows, 
                                            task=list(tasks_all.tid),
                                            output_format='dataframe'
                                            )

# rank evaluations
evals['rank'] = evals.groupby('task_id')['value'].rank('first', ascending=False)

# get best evaluations
best_evals = evals.loc[evals['rank'] <= 5]

# %%
best_evals.shape
# Out:
# (335, 15)

# %% [markdown]
# ## Check categorical / numerical / mixed features

# %%
# empty list to populate with feature types
types = []

for i in tasks_all.tid:
    print(i, '', end = '')
    
    # get task
    task = openml.tasks.get_task(i)

    # get dataset object 
    data = openml.datasets.get_dataset(task.dataset_id)

    # get relevant info from dataset object
    X, y, categorical_indicator, attribute_names = data.get_data(dataset_format='array',
                                                                target=data.default_target_attribute)
    
    if not any(categorical_indicator):
        types.append((i, 'numeric'))
    elif all(categorical_indicator):
        types.append((i, 'categorical'))
    else:
        types.append((i, 'mixed'))

cat_num = pd.DataFrame(types, columns = ['tid', 'cat_num'])
cat_num = pd.DataFrame(types, columns=['tid', 'cat_num'])
# Out:
# 3 6 11 12 14 15 16 18 22 23 28 29 31 32 37 43 45 49 53 219 2074 2079 3021 3022 3481 3549 3560 3902 3903 3904 3913 3917 3918 7592 9910 9946 9952 9957 9960 9964 9971 9976 9977 9978 9981 9985 10093 10101 14952 14954 14965 14969 14970 125920 125922 146195 146800 146817 146819 146820 146821 146822 146824 167119 167120 167125 167140 167141

# %%
cat_num
# Out:
#        tid      cat_num
# 0        3  categorical
# 1        6      numeric
# 2       11      numeric
# 3       12      numeric
# 4       14      numeric
# ..     ...          ...
# 63  167119      numeric
# 64  167120      numeric
# 65  167125        mixed
# 66  167140  categorical
# 67  167141        mixed
#
# [68 rows x 2 columns]

# %%
# check distribution
cat_num['cat_num'].value_counts()
# Out:
# numeric        45
# mixed          15
# categorical     8
# Name: cat_num, dtype: int64

# %%
# check ids of mixed feature tasks
list(cat_num.tid.loc[cat_num.cat_num == 'mixed'])
# Out:
# [23,
#  29,
#  31,
#  219,
#  2079,
#  3021,
#  3022,
#  7592,
#  9971,
#  9977,
#  14954,
#  14965,
#  125920,
#  167125,
#  167141]

# %%
task_ids = cat_num[cat_num.cat_num != 'mixed'].tid

# %% [markdown]
# ## Loop over all tasks

# %%
# define timeout handler
def handler(signum, frame):
    raise Exception("Timeout!")
    
# Register the signal function handler
signal.signal(signal.SIGALRM, handler)
# Out:
# <Handlers.SIG_DFL: 0>

# %%
# infinite loop
while 1:

    # randomly sample a task
    i = tasks_all.tid.sample().iloc[0] # this samples from all tasks
    #i = task_ids.sample() # sample from numeric or categorical only
    
    # get task
    task = openml.tasks.get_task(i)
    
    # get dataset object
    data = openml.datasets.get_dataset(task.dataset_id)

    # get relevant info from dataset object
    X, y, categorical_indicator, attribute_names = data.get_data(dataset_format='array',
                                                                target=data.default_target_attribute)

    # mask with feature types
    cat = categorical_indicator
    num = [not k for k in categorical_indicator]

    # create column transformers
    numeric_transformer = make_pipeline(#SimpleImputer(strategy='median'), 
                                        StandardScaler())

    categorical_transformer = make_pipeline(#SimpleImputer(strategy='most_frequent'),
                                            OneHotEncoder(handle_unknown='ignore'))

    preprocessor = ColumnTransformer(
    transformers=[
    ('num', numeric_transformer, num),
    ('cat', categorical_transformer, cat)])
    
    # loop over runs in random order
    for k in best_evals.run_id.sample(frac=1):
        
        # set time limit
        signal.alarm(3600)
        
        print('Run', k, 'on task', i)
        print(datetime.now())
        
        try:
            # get params
            params = get_run_info_rf(k)

            # define classifier
            clf = RandomForestClassifier(**params)

            # pick pipeline according to feature types
            if not any(categorical_indicator):
                pipe = make_pipeline(SimpleImputer(strategy='median'), StandardScaler(), clf)
            elif all(categorical_indicator):
                pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore'), clf)
            else:
                pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), preprocessor, clf)
                
            # run best model on the task
            run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=True)

            # print feedbackack
            print('Publish openml run...')

            # push tag
            # run.push_tag('best_models')
            # publish the run
            
            run.publish()
            # print feedback
            print('View run online: https://www.openml.org/r/' + str(run.run_id))
            print('Setup', openml.runs.get_run(run.run_id).setup_id)
            print('Flow', openml.runs.get_run(run.run_id).flow_id)
            print()

        except Exception as e:
            print(e)
# Out:
# Run 9197640 on task 9952
# 2020-04-05 12:40:53.308208
# Publish openml run...
# View run online: https://www.openml.org/r/10438368
# Setup 8261202
# Flow 17646
#
# Run 5798934 on task 9952
# 2020-04-05 12:40:59.333921
# Publish openml run...
# View run online: https://www.openml.org/r/10438369
# Setup 8261217
# Flow 17646
#
# Run 9199618 on task 9952
# 2020-04-05 12:41:15.400295
# One or more runs of this setup were already performed on the task.
# Run 10017324 on task 9952
# 2020-04-05 12:41:17.362633
# Publish openml run...
# View run online: https://www.openml.org/r/10438370
# Setup 8261268
# Flow 17646
#
# Run 6010547 on task 9952
# 2020-04-05 12:41:32.478030
# Publish openml run...
# View run online: https://www.openml.org/r/10438371
# Setup 8261269
# Flow 17646
#
# Run 1874802 on task 9952
# 2020-04-05 12:41:43.790930
# Publish openml run...
# View run online: https://www.openml.org/r/10438372
# Setup 8261267
# Flow 17646
#
# Run 9184549 on task 9952
# 2020-04-05 12:42:09.563709
# Publish openml run...
# View run online: https://www.openml.org/r/10438373
# Setup 8261270
# Flow 17646
#
# Run 9136702 on task 9952
# 2020-04-05 12:42:30.667936
# Publish openml run...
# View run online: https://www.openml.org/r/10438374
# Setup 8261271
# Flow 17646
#
# Run 9199524 on task 9952
# 2020-04-05 12:42:51.465490
# One or more runs of this setup were already performed on the task.
# Run 9031583 on task 9952
# 2020-04-05 12:42:53.897629
# Publish openml run...
# View run online: https://www.openml.org/r/10438375
# Setup 8261272
# Flow 17646
#
# Run 8920448 on task 9952
# 2020-04-05 12:43:21.023374
# Publish openml run...
# View run online: https://www.openml.org/r/10438376
# Setup 8261239
# Flow 17646
#
# Run 9054154 on task 9952
# 2020-04-05 12:44:13.439493
# Publish openml run...
# View run online: https://www.openml.org/r/10438377
# Setup 8261273
# Flow 17646
#
# Run 9005644 on task 9952
# 2020-04-05 12:44:49.520291
# Publish openml run...
# View run online: https://www.openml.org/r/10438378
# Setup 8261274
# Flow 17646
#
# Run 9195533 on task 9952
# 2020-04-05 12:45:21.314469
# One or more runs of this setup were already performed on the task.
# Run 1874375 on task 9952
# 2020-04-05 12:45:23.737961
# Publish openml run...
# View run online: https://www.openml.org/r/10438379
# Setup 8261275
# Flow 17646
#
# Run 1874881 on task 9952
# 2020-04-05 12:45:47.468928
# Publish openml run...
# View run online: https://www.openml.org/r/10438380
# Setup 8261276
# Flow 17646
#
# Run 9184785 on task 9952
# 2020-04-05 12:46:09.715844
# Publish openml run...
# View run online: https://www.openml.org/r/10438381
# Setup 8261277
# Flow 17646
#
# Run 9194475 on task 9952
# 2020-04-05 12:46:33.972563
# One or more runs of this setup were already performed on the task.
# Run 9174635 on task 9952
# 2020-04-05 12:46:37.033574
# Publish openml run...
# View run online: https://www.openml.org/r/10438382
# Setup 8261278
# Flow 17646
#
# Run 1874596 on task 9952
# 2020-04-05 12:47:02.518150
# One or more runs of this setup were already performed on the task.
# Run 9172987 on task 9952
# 2020-04-05 12:47:04.682418
# Publish openml run...
# View run online: https://www.openml.org/r/10438383
# Setup 8261255
# Flow 17646
#
# Run 9195908 on task 9952
# 2020-04-05 12:47:34.989767
# One or more runs of this setup were already performed on the task.
# Run 9198986 on task 9952
# 2020-04-05 12:47:37.686591
# One or more runs of this setup were already performed on the task.
# Run 1860779 on task 9952
# 2020-04-05 12:47:40.099232
# Publish openml run...
# View run online: https://www.openml.org/r/10438384
# Setup 8261279
# Flow 17646
#
# Run 9192302 on task 9952
# 2020-04-05 12:48:00.905868
# One or more runs of this setup were already performed on the task.
# Run 9198604 on task 9952
# 2020-04-05 12:48:03.111211
# One or more runs of this setup were already performed on the task.
# Run 10010497 on task 9952
# 2020-04-05 12:48:05.589628
# Publish openml run...
# View run online: https://www.openml.org/r/10438385
# Setup 8261280
# Flow 17646
#
# Run 9037766 on task 9952
# 2020-04-05 12:48:15.778259
# Publish openml run...
# View run online: https://www.openml.org/r/10438386
# Setup 8261281
# Flow 17646
#
# Run 9000888 on task 9952
# 2020-04-05 12:49:17.792091
# Publish openml run...
# View run online: https://www.openml.org/r/10438387
# Setup 8261231
# Flow 17646
#
# Run 6026200 on task 9952
# 2020-04-05 12:49:48.119209
# Publish openml run...
# View run online: https://www.openml.org/r/10438388
# Setup 8261238
# Flow 17646
#
# Run 9032768 on task 9952
# 2020-04-05 12:49:59.794395
# Publish openml run...
# View run online: https://www.openml.org/r/10438389
# Setup 8261282
# Flow 17646
#
# Run 5944902 on task 9952
# 2020-04-05 12:50:31.916430
# Publish openml run...
# View run online: https://www.openml.org/r/10438390
# Setup 8261283
# Flow 17646
#
# Run 5942891 on task 9952
# 2020-04-05 12:50:42.889120
# Publish openml run...
# View run online: https://www.openml.org/r/10438391
# Setup 8261284
# Flow 17646
#
# Run 9043827 on task 9952
# 2020-04-05 12:50:53.236550
# Publish openml run...
# View run online: https://www.openml.org/r/10438392
# Setup 8261220
# Flow 17646
#
# Run 9162493 on task 9952
# 2020-04-05 12:51:24.471948
# Publish openml run...
# View run online: https://www.openml.org/r/10438393
# Setup 8261260
# Flow 17646
#
# Run 9199504 on task 9952
# 2020-04-05 12:51:53.702923
# One or more runs of this setup were already performed on the task.
# Run 9161927 on task 9952
# 2020-04-05 12:51:57.137624
# Publish openml run...
# View run online: https://www.openml.org/r/10438394
# Setup 8261285
# Flow 17646
#
# Run 10039094 on task 9952
# 2020-04-05 12:52:17.269492
# Publish openml run...
# View run online: https://www.openml.org/r/10438395
# Setup 8261236
# Flow 17646
#
# Run 1874378 on task 9952
# 2020-04-05 12:52:29.289222
# Publish openml run...
# View run online: https://www.openml.org/r/10438396
# Setup 8261286
# Flow 17646
#
# Run 1874798 on task 9952
# 2020-04-05 12:52:50.626494
# Publish openml run...
# View run online: https://www.openml.org/r/10438397
# Setup 8261287
# Flow 17646
#
# Run 9196302 on task 9952
# 2020-04-05 12:53:13.733682
# One or more runs of this setup were already performed on the task.
# Run 9197271 on task 9952
# 2020-04-05 12:53:16.091358
# One or more runs of this setup were already performed on the task.
# Run 9086014 on task 9952
# 2020-04-05 12:53:18.422744
# Publish openml run...
# View run online: https://www.openml.org/r/10438398
# Setup 8261288
# Flow 17646
#
# Run 8965024 on task 9952
# 2020-04-05 12:53:59.102927
# Publish openml run...
# View run online: https://www.openml.org/r/10438399
# Setup 8261289
# Flow 17646
#
# Run 1874601 on task 9952
# 2020-04-05 12:54:29.060432
# One or more runs of this setup were already performed on the task.
# Run 9197533 on task 9952
# 2020-04-05 12:54:32.299781
# One or more runs of this setup were already performed on the task.
# Run 9181540 on task 9952
# 2020-04-05 12:54:34.563292
# Publish openml run...
# View run online: https://www.openml.org/r/10438400
