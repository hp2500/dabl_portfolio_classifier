# %% [markdown]
# # Best runs on all tasks

# %% [markdown]
# ## Import modules

# %%
# import modules
import openml
from openml import tasks, flows, runs
import sklearn
from sklearn import feature_selection
from sklearn.svm import SVC
import pandas as pd
import pprint
from collections import OrderedDict, Counter
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
import re
import random
import numpy as np
from datetime import datetime
import sys
import matplotlib.pyplot as plt
import json
from itertools import combinations
from utils.functions_analyze_runs import get_run_info_svc

# set api key
openml.config.apikey = open('.key', 'r').readline().strip('\n')
# Out:
# /miniconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
# get all supervised classification tasks
tasks_all = openml.tasks.list_tasks(task_type_id=1, output_format='dataframe', tag = 'OpenML-CC18')
# drop problematic tasks
tasks_all = tasks_all.drop([3573, 146825, 167121, 167124])

# %% [markdown]
# ## Get OpenML runs for SVC flows

# %%
# get SVC evals
good_flows = [6246, 6952, 8330, 6954, 7756, 5499, 8317, 7223, 6009, 7707, 6269, 5983, 16374, 16347, 16345]
evals = openml.evaluations.list_evaluations('area_under_roc_curve',
                                            flow= good_flows, 
                                            task=list(tasks_all.tid),
                                            output_format='dataframe'
                                            )

# rank evaluations
evals['rank'] = evals.groupby('task_id')['value'].rank('first', ascending=False)

# get best evaluations
best_evals = evals.loc[evals['rank'] <= 5]

# %%
# drop problematic runs
best_evals = best_evals[best_evals.run_id != 6148258]
best_evals = best_evals[best_evals.run_id != 8231647]

# %%
best_evals.shape
# Out:
# (336, 13)

# %% [markdown]
# ## Check categorical / numerical / mixed features

# %%
# empty list to populate with feature types
types = []

for i in tasks_all.tid:
    print(i, '', end = '')
    
    # get task
    task = openml.tasks.get_task(i)

    # get dataset object 
    data = openml.datasets.get_dataset(task.dataset_id)

    # get relevant info from dataset object
    X, y, categorical_indicator, attribute_names = data.get_data(dataset_format='array',
                                                                target=data.default_target_attribute)

    if not any(categorical_indicator):
        types.append((i, 'numeric'))
    elif all(categorical_indicator):
        types.append((i, 'categorical'))
    else:
        types.append((i, 'mixed'))

cat_num = pd.DataFrame(types, columns = ['tid', 'cat_num'])
cat_num = pd.DataFrame(types, columns=['tid', 'cat_num'])
# Out:
# 3 6 11 12 14 15 16 18 22 23 28 29 31 32 37 43 45 49 53 219 2074 2079 3021 3022 3481 3549 3560 3902 3903 3904 3913 3917 3918 7592 9910 9946 9952 9957 9960 9964 9971 9976 9977 9978 9981 9985 10093 10101 14952 14954 14965 14969 14970 125920 125922 146195 146800 146817 146819 146820 146821 146822 146824 167119 167120 167125 167140 167141

# %%
cat_num
# Out:
#        tid      cat_num
# 0        3  categorical
# 1        6      numeric
# 2       11      numeric
# 3       12      numeric
# 4       14      numeric
# 5       15      numeric
# 6       16      numeric
# 7       18      numeric
# 8       22      numeric
# 9       23        mixed
# 10      28      numeric
# 11      29        mixed
# 12      31        mixed
# 13      32      numeric
# 14      37      numeric
# 15      43      numeric
# 16      45  categorical
# 17      49  categorical
# 18      53      numeric
# 19     219        mixed
# 20    2074      numeric
# 21    2079        mixed
# 22    3021        mixed
# 23    3022        mixed
# 24    3481      numeric
# 25    3549      numeric
# 26    3560  categorical
# 27    3902      numeric
# 28    3903      numeric
# 29    3904      numeric
# ..     ...          ...
# 38    9960      numeric
# 39    9964      numeric
# 40    9971        mixed
# 41    9976      numeric
# 42    9977        mixed
# 43    9978      numeric
# 44    9981      numeric
# 45    9985      numeric
# 46   10093      numeric
# 47   10101      numeric
# 48   14952  categorical
# 49   14954        mixed
# 50   14965        mixed
# 51   14969      numeric
# 52   14970      numeric
# 53  125920        mixed
# 54  125922      numeric
# 55  146195  categorical
# 56  146800      numeric
# 57  146817      numeric
# 58  146819      numeric
# 59  146820      numeric
# 60  146821  categorical
# 61  146822      numeric
# 62  146824      numeric
# 63  167119      numeric
# 64  167120      numeric
# 65  167125        mixed
# 66  167140  categorical
# 67  167141        mixed
#
# [68 rows x 2 columns]

# %%
# check distribution
cat_num['cat_num'].value_counts()
# Out:
# numeric        45
# mixed          15
# categorical     8
# Name: cat_num, dtype: int64

# %%
# check ids of mixed feature tasks
list(cat_num.tid.loc[cat_num.cat_num == 'mixed'])
# Out:
# [23,
#  29,
#  31,
#  219,
#  2079,
#  3021,
#  3022,
#  7592,
#  9971,
#  9977,
#  14954,
#  14965,
#  125920,
#  167125,
#  167141]

# %% [markdown]
# ## Loop over all tasks

# %%
# infinite loop
while 1:

    # randomly sample a task
    i = tasks_all.tid.sample().iloc[0]
    
    # get task
    task = openml.tasks.get_task(i)
    
    # get dataset object 
    data = openml.datasets.get_dataset(task.dataset_id)

    # get relevant info from dataset object
    X, y, categorical_indicator, attribute_names = data.get_data(dataset_format='array',
                                                                target=data.default_target_attribute)

    # mask with feature types
    cat = categorical_indicator
    num = [not k for k in categorical_indicator]

    # create column transformers
    numeric_transformer = make_pipeline(#SimpleImputer(strategy='median'), 
                                        StandardScaler())

    categorical_transformer = make_pipeline(#SimpleImputer(strategy='most_frequent'),
                                            OneHotEncoder(handle_unknown='ignore'))

    preprocessor = ColumnTransformer(
    transformers=[
    ('num', numeric_transformer, num),
    ('cat', categorical_transformer, cat)])
    
    # loop over runs in random order
    for k in best_evals.run_id.sample(frac=1):
        
        print('Run', k, 'on task', i)
        print(datetime.now())
        
        try:
            # get params
            params = get_run_info_svc(k)

            # define classifier
            clf = SVC(**params)

            # pick pipeline according to feature types
            if not any(categorical_indicator):
                pipe = make_pipeline(SimpleImputer(strategy='median'), StandardScaler(), clf)
            elif all(categorical_indicator):
                pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore'), clf)
            else:
                pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), preprocessor, clf)
                
            # run best model on the task
            run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=True)

            # print feedbackack
            print('Publish openml run...')

            # push tag
            #run.push_tag('best_models')

            # publish the run 
            run.publish()
            # print feedback
            print('View run online: https://www.openml.org/r/' + str(run.run_id))
            print('Setup', openml.runs.get_run(run.run_id).setup_id)
            print('Flow', openml.runs.get_run(run.run_id).flow_id)
            print()

        except Exception as e:
            print(e)
# Out:
# Run 5939306 on task 49
# 2019-09-02 16:41:03.355763
# One or more runs of this setup were already performed on the task.
# Run 8726998 on task 49
# 2019-09-02 16:41:06.244442
# Publish openml run...
# View run online: https://www.openml.org/r/10397846
# Setup 8235794
# Flow 16366
#
# Run 6005547 on task 49
# 2019-09-02 16:41:12.333071
# Publish openml run...
# View run online: https://www.openml.org/r/10397847
# Setup 8235939
# Flow 16366
#
# Run 6060855 on task 49
# 2019-09-02 16:41:18.588755
# Publish openml run...
# View run online: https://www.openml.org/r/10397848
# Setup 8235853
# Flow 16366
#
# Run 8983496 on task 49
# 2019-09-02 16:41:24.475719
# Publish openml run...
# View run online: https://www.openml.org/r/10397849
# Setup 8235952
# Flow 16366
#
# Run 9202797 on task 49
# 2019-09-02 16:41:31.049296
# Publish openml run...
# View run online: https://www.openml.org/r/10397850
# Setup 8235850
# Flow 16366
#
# Run 6046419 on task 49
# 2019-09-02 16:41:38.544964
# One or more runs of this setup were already performed on the task.
# Run 9202653 on task 49
# 2019-09-02 16:41:40.889333
# Publish openml run...
# View run online: https://www.openml.org/r/10397851
# Setup 8235784
# Flow 16366
#
# Run 8983801 on task 49
# 2019-09-02 16:41:47.659629
# Publish openml run...
# View run online: https://www.openml.org/r/10397852
# Setup 8235913
# Flow 16366
#
# Run 8834569 on task 49
# 2019-09-02 16:41:54.102744
# Publish openml run...
# View run online: https://www.openml.org/r/10397853
# Setup 8235821
# Flow 16366
#
# Run 5958221 on task 49
# 2019-09-02 16:42:01.170250
# Publish openml run...
# View run online: https://www.openml.org/r/10397854
# Setup 8235681
# Flow 16366
#
# Run 8812020 on task 49
# 2019-09-02 16:42:08.854992
# Publish openml run...
# View run online: https://www.openml.org/r/10397855
# Setup 8235902
# Flow 16366
#
# Run 8826823 on task 49
# 2019-09-02 16:42:15.313883
# Publish openml run...
# View run online: https://www.openml.org/r/10397856
# Setup 8235832
# Flow 16366
#
# Run 9011384 on task 49
# 2019-09-02 16:42:21.115866
# Publish openml run...
# View run online: https://www.openml.org/r/10397857
# Setup 8235841
# Flow 16366
#
# Run 9202870 on task 49
# 2019-09-02 16:42:29.529161
# Publish openml run...
# View run online: https://www.openml.org/r/10397858
# Setup 8235700
# Flow 16366
#
# Run 9202016 on task 49
# 2019-09-02 16:42:36.498836
# Publish openml run...
# View run online: https://www.openml.org/r/10397859
# Setup 8235924
# Flow 16366
#
# Run 6123170 on task 49
# 2019-09-02 16:42:44.184185
# Publish openml run...
# View run online: https://www.openml.org/r/10397860
# Setup 8235754
# Flow 16366
#
# Run 10382972 on task 49
# 2019-09-02 16:42:51.242483
# Publish openml run...
# View run online: https://www.openml.org/r/10397861
# Setup 8235708
# Flow 16366
#
# Run 9202485 on task 49
# 2019-09-02 16:42:57.254897
# Publish openml run...
# View run online: https://www.openml.org/r/10397862
# Setup 8235788
# Flow 16366
#
# Run 6042866 on task 49
# 2019-09-02 16:43:08.538656
# Publish openml run...
# View run online: https://www.openml.org/r/10397863
# Setup 8235753
# Flow 16366
#
# Run 8834156 on task 49
# 2019-09-02 16:43:14.909136
# Publish openml run...
# View run online: https://www.openml.org/r/10397864
# Setup 8235716
# Flow 16366
#
# Run 8822644 on task 49
# 2019-09-02 16:43:21.350474
# Publish openml run...
# View run online: https://www.openml.org/r/10397865
# Setup 8235894
# Flow 16366
#
# Run 2036039 on task 49
# 2019-09-02 16:43:27.156928
# Publish openml run...
# View run online: https://www.openml.org/r/10397866
# Setup 8235819
# Flow 16366
#
# Run 6045925 on task 49
# 2019-09-02 16:43:34.008394
# Publish openml run...
# View run online: https://www.openml.org/r/10397867
# Setup 8235898
# Flow 16366
#
# Run 8702001 on task 49
# 2019-09-02 16:43:39.364492
# Publish openml run...
# View run online: https://www.openml.org/r/10397868
# Setup 8235665
# Flow 16366
#
# Run 9059106 on task 49
# 2019-09-02 16:43:44.743176
# Publish openml run...
# View run online: https://www.openml.org/r/10397869
# Setup 8235779
# Flow 16366
#
# Run 9202898 on task 49
# 2019-09-02 16:43:50.974331
# Publish openml run...
# View run online: https://www.openml.org/r/10397870
# Setup 8235979
# Flow 16366
#
# Run 9202607 on task 49
# 2019-09-02 16:43:58.474604
# Publish openml run...
# View run online: https://www.openml.org/r/10397871
# Setup 8235933
# Flow 16366
#
# Run 8696108 on task 49
# 2019-09-02 16:44:04.239037
# Publish openml run...
# View run online: https://www.openml.org/r/10397872
# Setup 8235663
# Flow 16366
#
# Run 8827790 on task 49
# 2019-09-02 16:44:10.170496
# Publish openml run...
# View run online: https://www.openml.org/r/10397873
# Setup 8235838
# Flow 16366
#
# Run 6065656 on task 49
# 2019-09-02 16:44:16.928387
# Publish openml run...
# View run online: https://www.openml.org/r/10397874
# Setup 8235800
# Flow 16366
#
# Run 6061916 on task 49
# 2019-09-02 16:44:24.584982
# Publish openml run...
# View run online: https://www.openml.org/r/10397875
# Setup 8235839
# Flow 16366
#
# Run 6040902 on task 49
# 2019-09-02 16:44:30.459811
# Publish openml run...
# View run online: https://www.openml.org/r/10397876
# Setup 8235755
# Flow 16366
#
# Run 9202979 on task 49
# 2019-09-02 16:44:37.393010
# Publish openml run...
# View run online: https://www.openml.org/r/10397877
# Setup 8235655
# Flow 16366
#
# Run 9202942 on task 49
# 2019-09-02 16:44:43.656291
# Publish openml run...
# View run online: https://www.openml.org/r/10397878
# Setup 8235684
# Flow 16366
#
# Run 8697166 on task 49
# 2019-09-02 16:44:49.720516
# Publish openml run...
# View run online: https://www.openml.org/r/10397879
# Setup 8235668
# Flow 16366
#
# Run 5192367 on task 49
# 2019-09-02 16:44:55.982414
# Publish openml run...
# View run online: https://www.openml.org/r/10397880
# Setup 8235777
# Flow 16366
#
# Run 6140640 on task 49
# 2019-09-02 16:45:02.327544
# Publish openml run...
# View run online: https://www.openml.org/r/10397881
# Setup 8235728
# Flow 16366
#
# Run 6042178 on task 49
# 2019-09-02 16:45:12.555979
# Publish openml run...
# View run online: https://www.openml.org/r/10397882
# Setup 8235909
# Flow 16366
#
# Run 9202126 on task 49
# 2019-09-02 16:45:19.621833
# Publish openml run...
# View run online: https://www.openml.org/r/10397883
# Setup 8235745
# Flow 16366
#
# Run 8707023 on task 49
# 2019-09-02 16:45:26.041191
# Publish openml run...
# View run online: https://www.openml.org/r/10397884
# Setup 8235673
# Flow 16366
#
# Run 8994189 on task 49
# 2019-09-02 16:45:33.206109
# Publish openml run...
# View run online: https://www.openml.org/r/10397885
# Setup 8235702
# Flow 16366
#
# Run 8729794 on task 49
# 2019-09-02 16:45:40.520877
# Publish openml run...
# View run online: https://www.openml.org/r/10397886
# Setup 8235923
# Flow 16366
#
# Run 6045896 on task 49
# 2019-09-02 16:45:47.270441
# Publish openml run...
# View run online: https://www.openml.org/r/10397887
# Setup 8235717
# Flow 16366
#
# Run 4750755 on task 49
# 2019-09-02 16:45:53.209562
# Publish openml run...
# View run online: https://www.openml.org/r/10397888
# Setup 8235840
# Flow 16366
#
# Run 10376362 on task 49
# 2019-09-02 16:46:00.492446
# Publish openml run...
# View run online: https://www.openml.org/r/10397889
# Setup 8235756
# Flow 16366
#
# Run 8829573 on task 49
# 2019-09-02 16:46:06.930115
# Publish openml run...
# View run online: https://www.openml.org/r/10397890
# Setup 8235866
# Flow 16366
#
# Run 8729218 on task 49
# 2019-09-02 16:46:11.593462
# One or more runs of this setup were already performed on the task.
# Run 6055496 on task 49
# 2019-09-02 16:46:13.705929
# One or more runs of this setup were already performed on the task.
# Run 6035690 on task 49
# 2019-09-02 16:46:15.894636
# Publish openml run...
# View run online: https://www.openml.org/r/10397891
# Setup 8235752
# Flow 16366
#
# Run 6130768 on task 49
# 2019-09-02 16:46:23.052629
# One or more runs of this setup were already performed on the task.
# Run 6065128 on task 49
# 2019-09-02 16:46:25.358671
# Publish openml run...
# View run online: https://www.openml.org/r/10397892
# Setup 8235890
# Flow 16366
#
# Run 8977686 on task 49
# 2019-09-02 16:46:31.804644
# Publish openml run...
# View run online: https://www.openml.org/r/10397893
# Setup 8235675
# Flow 16366
#
# Run 5945674 on task 49
# 2019-09-02 16:46:38.387432
# Publish openml run...
# View run online: https://www.openml.org/r/10397894
# Setup 8235910
# Flow 16366
#
# Run 8708418 on task 49
# 2019-09-02 16:46:43.978448
# Publish openml run...
# View run online: https://www.openml.org/r/10397895
# Setup 8235905
# Flow 16366
#
# Run 8827942 on task 49
# 2019-09-02 16:46:49.700133
# One or more runs of this setup were already performed on the task.
# Run 8697657 on task 49
# 2019-09-02 16:46:52.511043
# Publish openml run...
# View run online: https://www.openml.org/r/10397896
# Setup 8235662
# Flow 16366
#
# Run 9200440 on task 49
# 2019-09-02 16:46:59.008069
# name 'auto' is not defined
# Run 8848691 on task 49
# 2019-09-02 16:46:59.049932
# Publish openml run...
# View run online: https://www.openml.org/r/10397897
# Setup 8235722
# Flow 16366
#
# Run 8843257 on task 49
# 2019-09-02 16:47:05.492419
# Publish openml run...
# View run online: https://www.openml.org/r/10397898
# Setup 8235765
# Flow 16366
#
# Run 9202994 on task 49
# 2019-09-02 16:47:16.103735
# Publish openml run...
# View run online: https://www.openml.org/r/10397899
# Setup 8235698
# Flow 16366
#
# Run 9201957 on task 49
# 2019-09-02 16:47:23.369506
# Publish openml run...
# View run online: https://www.openml.org/r/10397900
# Setup 8235878
# Flow 16366
#
# Run 8812964 on task 49
# 2019-09-02 16:47:29.850710
# One or more runs of this setup were already performed on the task.
# Run 8697848 on task 49
# 2019-09-02 16:47:33.406947
# Publish openml run...
# View run online: https://www.openml.org/r/10397901
# Setup 8235686
# Flow 16366
#
# Run 6147040 on task 49
# 2019-09-02 16:47:39.719439
# Publish openml run...
# View run online: https://www.openml.org/r/10397902
# Setup 8235887
# Flow 16366
#
# Run 8834257 on task 49
# 2019-09-02 16:47:45.854840
# One or more runs of this setup were already performed on the task.
# Run 8817114 on task 49
# 2019-09-02 16:47:48.731292
# One or more runs of this setup were already performed on the task.
# Run 8700114 on task 49
# 2019-09-02 16:47:52.297626
# Publish openml run...
# View run online: https://www.openml.org/r/10397903
# Setup 8235803
# Flow 16366
#
# Run 6040703 on task 49
# 2019-09-02 16:47:58.435084
# Publish openml run...
# View run online: https://www.openml.org/r/10397904
# Setup 8235768
# Flow 16366
#
# Run 9202177 on task 49
# 2019-09-02 16:48:06.647376
# Publish openml run...
# View run online: https://www.openml.org/r/10397905
# Setup 8235674
# Flow 16366
#
# Run 8814855 on task 49
# 2019-09-02 16:48:12.876616
# Publish openml run...
# View run online: https://www.openml.org/r/10397906
# Setup 8235903
# Flow 16366
#
# Run 8815908 on task 49
# 2019-09-02 16:48:19.882986
# Publish openml run...
# View run online: https://www.openml.org/r/10397907
# Setup 8235925
# Flow 16366
#
# Run 5947544 on task 49
# 2019-09-02 16:48:28.864286
# Publish openml run...
# View run online: https://www.openml.org/r/10397908
# Setup 8235938
# Flow 16366
#
# Run 8737515 on task 49
# 2019-09-02 16:48:34.868907
# Publish openml run...
# View run online: https://www.openml.org/r/10397909
# Setup 8235931
# Flow 16366
#
# Run 8699314 on task 49
# 2019-09-02 16:48:40.628040
# Publish openml run...
# View run online: https://www.openml.org/r/10397910
# Setup 8235901
# Flow 16366
#
# Run 6054637 on task 49
# 2019-09-02 16:48:47.470764
# Publish openml run...
# View run online: https://www.openml.org/r/10397911
# Setup 8235705
# Flow 16366
#
# Run 8826438 on task 49
# 2019-09-02 16:48:54.195285
# Publish openml run...
# View run online: https://www.openml.org/r/10397912
# Setup 8235884
# Flow 16366
#
# Run 8729808 on task 49
# 2019-09-02 16:49:01.022887
# Publish openml run...
# View run online: https://www.openml.org/r/10397913
# Setup 8235677
# Flow 16366
#
# Run 6057941 on task 49
# 2019-09-02 16:49:08.800936
# Publish openml run...
# View run online: https://www.openml.org/r/10397914
# Setup 8235969
# Flow 16366
#
# Run 5898730 on task 49
# 2019-09-02 16:49:14.946137
# Publish openml run...
# View run online: https://www.openml.org/r/10397915
# Setup 8235672
# Flow 16366
#
# Run 8812346 on task 49
# 2019-09-02 16:49:21.664148
# Publish openml run...
# View run online: https://www.openml.org/r/10397916
# Setup 8235907
# Flow 16366
#
# Run 8827829 on task 49
# 2019-09-02 16:49:28.680863
# One or more runs of this setup were already performed on the task.
# Run 9202013 on task 49
# 2019-09-02 16:49:30.937021
# Publish openml run...
# View run online: https://www.openml.org/r/10397917
# Setup 8235948
# Flow 16366
#
# Run 8822102 on task 49
# 2019-09-02 16:49:37.341221
# Publish openml run...
# View run online: https://www.openml.org/r/10397918
# Setup 8235769
# Flow 16366
#
# Run 10321760 on task 49
# 2019-09-02 16:49:43.408316
# Publish openml run...
# View run online: https://www.openml.org/r/10397919
# Setup 8235733
# Flow 16366
#
# Run 8814189 on task 49
# 2019-09-02 16:49:49.002736
# Publish openml run...
# View run online: https://www.openml.org/r/10397920
# Setup 8235676
# Flow 16366
#
# Run 9202783 on task 49
# 2019-09-02 16:49:55.193641
# Publish openml run...
# View run online: https://www.openml.org/r/10397921
# Setup 8235710
# Flow 16366
#
# Run 8849281 on task 49
# 2019-09-02 16:50:01.346086
# Publish openml run...
# View run online: https://www.openml.org/r/10397922
# Setup 8235869
# Flow 16366
#
# Run 8837191 on task 49
# 2019-09-02 16:50:07.470858
# Publish openml run...
# View run online: https://www.openml.org/r/10397923
# Setup 8235782
# Flow 16366
#
# Run 4569642 on task 49
# 2019-09-02 16:50:13.672451
# Publish openml run...
# View run online: https://www.openml.org/r/10397924
# Setup 8235870
# Flow 16366
#
# Run 8830529 on task 49
# 2019-09-02 16:50:21.313670
# Publish openml run...
# View run online: https://www.openml.org/r/10397925
# Setup 8235862
# Flow 16366
#
# Run 2088222 on task 49
# 2019-09-02 16:50:28.060278
# Publish openml run...
# View run online: https://www.openml.org/r/10397926
# Setup 8235860
# Flow 16366
#
# Run 6035362 on task 49
# 2019-09-02 16:50:36.323184
# Publish openml run...
# View run online: https://www.openml.org/r/10397927
# Setup 8235896
# Flow 16366
#
# Run 8990490 on task 49
# 2019-09-02 16:50:43.732652
# Publish openml run...
# View run online: https://www.openml.org/r/10397928
# Setup 8235877
# Flow 16366
#
# Run 8698720 on task 49
# 2019-09-02 16:50:50.641569
# Publish openml run...
# View run online: https://www.openml.org/r/10397929
# Setup 8235810
# Flow 16366
#
# Run 10321390 on task 49
# 2019-09-02 16:51:02.056127
# One or more runs of this setup were already performed on the task.
# Run 9202157 on task 49
# 2019-09-02 16:51:04.829789
# Publish openml run...
# View run online: https://www.openml.org/r/10397930
# Setup 8235942
# Flow 16366
#
# Run 8824660 on task 49
# 2019-09-02 16:51:11.961393
# Publish openml run...
# View run online: https://www.openml.org/r/10397931
# Setup 8235854
# Flow 16366
#
# Run 8811297 on task 49
# 2019-09-02 16:51:18.053219
# Publish openml run...
# View run online: https://www.openml.org/r/10397932
# Setup 8235774
# Flow 16366
#
# Run 8727711 on task 49
# 2019-09-02 16:51:24.567783
# Publish openml run...
# View run online: https://www.openml.org/r/10397933
# Setup 8235858
# Flow 16366
#
# Run 6043669 on task 49
# 2019-09-02 16:51:31.667172
# Publish openml run...
# View run online: https://www.openml.org/r/10397934
# Setup 8235802
# Flow 16366
#
# Run 9202421 on task 49
# 2019-09-02 16:51:38.402103
# Publish openml run...
# View run online: https://www.openml.org/r/10397935
# Setup 8235748
# Flow 16366
#
# Run 6799683 on task 49
# 2019-09-02 16:51:43.643215
# Publish openml run...
# View run online: https://www.openml.org/r/10397936
# Setup 8235746
# Flow 16366
#
# Run 9202960 on task 49
# 2019-09-02 16:51:51.925895
# Publish openml run...
# View run online: https://www.openml.org/r/10397937
# Setup 8235736
# Flow 16366
#
# Run 7448774 on task 49
# 2019-09-02 16:51:58.678143
# Publish openml run...
# View run online: https://www.openml.org/r/10397938
# Setup 8235743
# Flow 16366
#
# Run 5987661 on task 49
# 2019-09-02 16:52:06.669787
# One or more runs of this setup were already performed on the task.
# Run 8850476 on task 49
# 2019-09-02 16:52:09.322391
# Publish openml run...
# View run online: https://www.openml.org/r/10397939
# Setup 8235678
# Flow 16366
#
# Run 9202634 on task 49
# 2019-09-02 16:52:16.385898
# Publish openml run...
# View run online: https://www.openml.org/r/10397940
# Setup 8235888
# Flow 16366
#
# Run 9202983 on task 49
# 2019-09-02 16:52:23.225870
# Publish openml run...
# View run online: https://www.openml.org/r/10397941
# Setup 8235789
# Flow 16366
#
# Run 8734854 on task 49
# 2019-09-02 16:52:31.545210
# One or more runs of this setup were already performed on the task.
# Run 8846592 on task 49
# 2019-09-02 16:52:33.858558
# Publish openml run...
# View run online: https://www.openml.org/r/10397942
# Setup 8235719
# Flow 16366
#
# Run 4752667 on task 49
# 2019-09-02 16:52:40.161571
# Publish openml run...
# View run online: https://www.openml.org/r/10397943
# Setup 8235812
# Flow 16366
#
# Run 5970635 on task 49
# 2019-09-02 16:52:48.966203
# Publish openml run...
# View run online: https://www.openml.org/r/10397944
# Setup 8235940
# Flow 16366
#
# Run 10383140 on task 49
# 2019-09-02 16:52:55.514922
# Publish openml run...
# View run online: https://www.openml.org/r/10397945
# Setup 8235656
# Flow 16366
#
# Run 9202708 on task 49
# 2019-09-02 16:53:01.527852
# Publish openml run...
# View run online: https://www.openml.org/r/10397946
# Setup 8235817
# Flow 16366
#
# Run 8816158 on task 49
# 2019-09-02 16:53:08.724594
# Publish openml run...
# View run online: https://www.openml.org/r/10397947
# Setup 8235973
# Flow 16366
#
# Run 8813676 on task 49
# 2019-09-02 16:53:15.558937
# Publish openml run...
# View run online: https://www.openml.org/r/10397948
# Setup 8235826
# Flow 16366
#
# Run 6220541 on task 49
# 2019-09-02 16:53:21.875623
# One or more runs of this setup were already performed on the task.
# Run 5257991 on task 49
# 2019-09-02 16:53:24.693092
# Publish openml run...
# View run online: https://www.openml.org/r/10397949
# Setup 8235959
# Flow 16366
#
# Run 9200901 on task 49
# 2019-09-02 16:53:31.696388
# name 'auto' is not defined
# Run 8814784 on task 49
# 2019-09-02 16:53:31.725063
# Publish openml run...
# View run online: https://www.openml.org/r/10397950
# Setup 8235836
# Flow 16366
#
# Run 8748970 on task 49
# 2019-09-02 16:53:38.395826
# Publish openml run...
# View run online: https://www.openml.org/r/10397951
# Setup 8235968
# Flow 16366
#
# Run 8745403 on task 49
# 2019-09-02 16:53:44.660202
# Publish openml run...
# View run online: https://www.openml.org/r/10397952
# Setup 8235727
# Flow 16366
#
# Run 6047445 on task 49
# 2019-09-02 16:53:50.970871
# Publish openml run...
# View run online: https://www.openml.org/r/10397953
# Setup 8235941
# Flow 16366
#
# Run 5959935 on task 49
# 2019-09-02 16:54:00.648795
# Publish openml run...
# View run online: https://www.openml.org/r/10397954
# Setup 8235798
# Flow 16366
#
# Run 6045888 on task 49
# 2019-09-02 16:54:06.637120
# One or more runs of this setup were already performed on the task.
# Run 8726329 on task 49
# 2019-09-02 16:54:08.928403
# Publish openml run...
# View run online: https://www.openml.org/r/10397955
# Setup 8235735
# Flow 16366
#
# Run 7328806 on task 49
# 2019-09-02 16:54:14.522884
# Publish openml run...
# View run online: https://www.openml.org/r/10397956
# Setup 8235687
# Flow 16366
#
# Run 8840661 on task 49
# 2019-09-02 16:54:21.688348
# Publish openml run...
# View run online: https://www.openml.org/r/10397957
# Setup 8235828
# Flow 16366
#
# Run 8731559 on task 49
# 2019-09-02 16:54:27.884216
# Publish openml run...
# View run online: https://www.openml.org/r/10397958
# Setup 8235771
# Flow 16366
#
# Run 8816289 on task 49
# 2019-09-02 16:54:33.921954
# One or more runs of this setup were already performed on the task.
# Run 8735662 on task 49
# 2019-09-02 16:54:36.268913
# Publish openml run...
# View run online: https://www.openml.org/r/10397959
# Setup 8235787
# Flow 16366
#
# Run 4573535 on task 49
# 2019-09-02 16:54:42.089480
# One or more runs of this setup were already performed on the task.
# Run 6038418 on task 49
# 2019-09-02 16:54:44.869222
# Publish openml run...
# View run online: https://www.openml.org/r/10397960
# Setup 8235729
# Flow 16366
#
# Run 10376348 on task 49
# 2019-09-02 16:54:50.407221
# One or more runs of this setup were already performed on the task.
# Run 5368761 on task 49
# 2019-09-02 16:54:53.077537
# One or more runs of this setup were already performed on the task.
# Run 5940168 on task 49
# 2019-09-02 16:54:56.074333
# Publish openml run...
# View run online: https://www.openml.org/r/10397961
# Setup 8235701
# Flow 16366
#
# Run 4797269 on task 49
# 2019-09-02 16:55:01.791634
# Publish openml run...
# View run online: https://www.openml.org/r/10397962
# Setup 8235714
# Flow 16366
#
# Run 6066405 on task 49
# 2019-09-02 16:55:07.914226
# Publish openml run...
# View run online: https://www.openml.org/r/10397963
# Setup 8235928
# Flow 16366
#
# Run 8984144 on task 49
# 2019-09-02 16:55:15.230752
# Publish openml run...
# View run online: https://www.openml.org/r/10397964
# Setup 8235766
# Flow 16366
#
# Run 5943099 on task 49
# 2019-09-02 16:55:23.588784
# Publish openml run...
# View run online: https://www.openml.org/r/10397965
# Setup 8235799
# Flow 16366
#
# Run 8726440 on task 49
# 2019-09-02 16:55:29.122627
# Publish openml run...
# View run online: https://www.openml.org/r/10397966
# Setup 8235908
# Flow 16366
#
# Run 6056722 on task 49
# 2019-09-02 16:55:38.330644
# Publish openml run...
# View run online: https://www.openml.org/r/10397967
# Setup 8235679
# Flow 16366
#
# Run 8750135 on task 49
# 2019-09-02 16:55:56.171019
# Publish openml run...
# View run online: https://www.openml.org/r/10397968
# Setup 8235795
# Flow 16366
#
# Run 8837975 on task 49
# 2019-09-02 16:56:01.952952
# Publish openml run...
# View run online: https://www.openml.org/r/10397969
# Setup 8235946
# Flow 16366
#
# Run 6148438 on task 49
# 2019-09-02 16:56:07.818042
# Publish openml run...
# View run online: https://www.openml.org/r/10397970
# Setup 8235844
# Flow 16366
#
# Run 6141650 on task 49
# 2019-09-02 16:56:14.763919
# Publish openml run...
# View run online: https://www.openml.org/r/10397971
# Setup 8235747
# Flow 16366
#
# Run 6034690 on task 49
# 2019-09-02 16:56:21.029840
# One or more runs of this setup were already performed on the task.
# Run 8826085 on task 49
# 2019-09-02 16:56:23.619111
# Publish openml run...
# View run online: https://www.openml.org/r/10397972
# Setup 8235764
# Flow 16366
#
# Run 8985244 on task 49
# 2019-09-02 16:56:30.810502
# Publish openml run...
# View run online: https://www.openml.org/r/10397973
# Setup 8235731
# Flow 16366
#
# Run 1985158 on task 49
# 2019-09-02 16:56:36.164067
# Publish openml run...
# View run online: https://www.openml.org/r/10397974
# Setup 8235791
# Flow 16366
#
# Run 8700643 on task 49
# 2019-09-02 16:56:41.918602
# Publish openml run...
# View run online: https://www.openml.org/r/10397975
# Setup 8235804
# Flow 16366
#
# Run 8696510 on task 49
# 2019-09-02 16:56:48.976597
# Publish openml run...
# View run online: https://www.openml.org/r/10397976
# Setup 8235685
# Flow 16366
#
# Run 7505447 on task 49
# 2019-09-02 16:56:54.189587
# Publish openml run...
# View run online: https://www.openml.org/r/10397977
# Setup 8235915
# Flow 16366
#
# Run 8696020 on task 49
# 2019-09-02 16:57:03.585511
# Publish openml run...
# View run online: https://www.openml.org/r/10397979
# Setup 8235875
# Flow 16366
#
# Run 6124155 on task 49
# 2019-09-02 16:57:11.716220
# Publish openml run...
# View run online: https://www.openml.org/r/10397980
# Setup 8235955
# Flow 16366
#
# Run 8826601 on task 49
# 2019-09-02 16:57:23.547775
# Publish openml run...
# View run online: https://www.openml.org/r/10397981
# Setup 8235806
# Flow 16366
#
# Run 8729296 on task 49
# 2019-09-02 16:57:31.669802
# Publish openml run...
# View run online: https://www.openml.org/r/10397982
# Setup 8235709
# Flow 16366
#
# Run 6062121 on task 49
# 2019-09-02 16:57:37.797712
# Publish openml run...
# View run online: https://www.openml.org/r/10397983
# Setup 8235750
# Flow 16366
#
# Run 4697518 on task 49
# 2019-09-02 16:57:44.902145
# Publish openml run...
# View run online: https://www.openml.org/r/10397984
# Setup 8235688
# Flow 16366
#
# Run 6063709 on task 49
# 2019-09-02 16:57:51.648888
# Publish openml run...
# View run online: https://www.openml.org/r/10397985
# Setup 8235975
# Flow 16366
#
# Run 9201804 on task 49
# 2019-09-02 16:57:58.723462
# Publish openml run...
# View run online: https://www.openml.org/r/10397986
# Setup 8235786
# Flow 16366
#
# Run 6013835 on task 49
# 2019-09-02 16:58:05.300711
# Publish openml run...
# View run online: https://www.openml.org/r/10397987
# Setup 8235815
# Flow 16366
#
# Run 8695715 on task 49
# 2019-09-02 16:58:11.320516
# Publish openml run...
# View run online: https://www.openml.org/r/10397988
# Setup 8235895
# Flow 16366
#
# Run 8729014 on task 49
# 2019-09-02 16:58:17.148338
# Publish openml run...
# View run online: https://www.openml.org/r/10397989
# Setup 8235703
# Flow 16366
#
# Run 6302036 on task 49
# 2019-09-02 16:58:24.521585
# One or more runs of this setup were already performed on the task.
# Run 6049805 on task 49
# 2019-09-02 16:58:28.206520
# Publish openml run...
# View run online: https://www.openml.org/r/10397990
# Setup 8235906
# Flow 16366
#
# Run 8851753 on task 49
# 2019-09-02 16:58:34.972010
# Publish openml run...
# View run online: https://www.openml.org/r/10397991
# Setup 8235712
# Flow 16366
#
# Run 6057142 on task 49
# 2019-09-02 16:58:43.385814
# Publish openml run...
# View run online: https://www.openml.org/r/10397992
# Setup 8235849
# Flow 16366
#
# Run 8992449 on task 49
# 2019-09-02 16:58:52.485236
# One or more runs of this setup were already performed on the task.
# Run 5934664 on task 49
# 2019-09-02 16:58:55.788097
# One or more runs of this setup were already performed on the task.
# Run 4712742 on task 49
# 2019-09-02 16:58:58.616138
# Publish openml run...
# View run online: https://www.openml.org/r/10397993
# Setup 8235977
# Flow 16366
#
# Run 5945675 on task 49
# 2019-09-02 16:59:05.835881
# Publish openml run...
# View run online: https://www.openml.org/r/10397994
# Setup 8235834
# Flow 16366
#
# Run 7346175 on task 49
# 2019-09-02 16:59:11.830889
# One or more runs of this setup were already performed on the task.
# Run 8741229 on task 49
# 2019-09-02 16:59:14.898387
# Publish openml run...
# View run online: https://www.openml.org/r/10397995
# Setup 8235944
# Flow 16366
#
# Run 8739373 on task 49
# 2019-09-02 16:59:20.597990
# Publish openml run...
# View run online: https://www.openml.org/r/10397996
# Setup 8235704
# Flow 16366
#
# Run 10369671 on task 49
# 2019-09-02 16:59:26.887896
# Publish openml run...
# View run online: https://www.openml.org/r/10397997
# Setup 8235945
# Flow 16366
#
# Run 9202392 on task 49
# 2019-09-02 16:59:35.671761
# Publish openml run...
# View run online: https://www.openml.org/r/10397998
# Setup 8235861
# Flow 16366
#
# Run 8839285 on task 49
# 2019-09-02 16:59:41.650775
# Publish openml run...
# View run online: https://www.openml.org/r/10397999
# Setup 8235776
# Flow 16366
#
# Run 6042851 on task 49
# 2019-09-02 16:59:47.941856
# Publish openml run...
# View run online: https://www.openml.org/r/10398000
# Setup 8235822
# Flow 16366
#
# Run 8698113 on task 49
# 2019-09-02 16:59:56.071404
# Publish openml run...
# View run online: https://www.openml.org/r/10398001
# Setup 8235926
# Flow 16366
#
# Run 7321131 on task 49
# 2019-09-02 17:00:03.632201
# Publish openml run...
# View run online: https://www.openml.org/r/10398002
# Setup 8235873
# Flow 16366
#
# Run 5921820 on task 49
# 2019-09-02 17:00:11.134897
# Publish openml run...
# View run online: https://www.openml.org/r/10398003
# Setup 8235823
# Flow 16366
#
# Run 8816591 on task 49
# 2019-09-02 17:00:16.826181
# Publish openml run...
# View run online: https://www.openml.org/r/10398004
# Setup 8235773
# Flow 16366
#
# Run 8850454 on task 49
# 2019-09-02 17:00:23.719320
# Publish openml run...
# View run online: https://www.openml.org/r/10398005
# Setup 8235885
# Flow 16366
#
# Run 9201805 on task 49
# 2019-09-02 17:00:30.787810
# Publish openml run...
# View run online: https://www.openml.org/r/10398006
# Setup 8235706
# Flow 16366
#
# Run 8695563 on task 49
# 2019-09-02 17:00:36.443888
# Publish openml run...
# View run online: https://www.openml.org/r/10398007
# Setup 8235970
# Flow 16366
#
# Run 9200913 on task 49
# 2019-09-02 17:00:42.953027
# name 'auto' is not defined
# Run 10362529 on task 49
# 2019-09-02 17:00:42.976167
# Publish openml run...
# View run online: https://www.openml.org/r/10398008
# Setup 8235671
# Flow 16366
#
# Run 5935828 on task 49
# 2019-09-02 17:00:48.292959
# One or more runs of this setup were already performed on the task.
# Run 10350488 on task 49
# 2019-09-02 17:00:50.677922
# One or more runs of this setup were already performed on the task.
# Run 8979192 on task 49
# 2019-09-02 17:00:52.972053
# Publish openml run...
# View run online: https://www.openml.org/r/10398009
# Setup 8235852
# Flow 16366
#
# Run 6050505 on task 49
# 2019-09-02 17:00:59.326488
# Publish openml run...
# View run online: https://www.openml.org/r/10398010
# Setup 8235950
# Flow 16366
#
# Run 4568739 on task 49
# 2019-09-02 17:01:05.510529
# Publish openml run...
# View run online: https://www.openml.org/r/10398011
# Setup 8235820
# Flow 16366
#
# Run 6052536 on task 49
# 2019-09-02 17:01:12.021492
# Publish openml run...
# View run online: https://www.openml.org/r/10398012
# Setup 8235978
# Flow 16366
#
# Run 9202916 on task 49
# 2019-09-02 17:01:18.091513
# Publish openml run...
# View run online: https://www.openml.org/r/10398013
# Setup 8235757
# Flow 16366
#
# Run 8835524 on task 49
# 2019-09-02 17:01:25.332604
# Publish openml run...
# View run online: https://www.openml.org/r/10398014
# Setup 8235770
# Flow 16366
#
# Run 8703172 on task 49
# 2019-09-02 17:01:31.302294
# Publish openml run...
# View run online: https://www.openml.org/r/10398015
# Setup 8235781
# Flow 16366
#
# Run 9011260 on task 49
# 2019-09-02 17:01:37.625004
# One or more runs of this setup were already performed on the task.
# Run 8991715 on task 49
# 2019-09-02 17:01:39.923572
# Publish openml run...
# View run online: https://www.openml.org/r/10398016
# Setup 8235947
# Flow 16366
#
# Run 8699489 on task 49
# 2019-09-02 17:01:45.814936
# Publish openml run...
# View run online: https://www.openml.org/r/10398017
# Setup 8235796
# Flow 16366
#
# Run 9202508 on task 49
# 2019-09-02 17:01:52.342251
# Publish openml run...
# View run online: https://www.openml.org/r/10398018
# Setup 8235960
# Flow 16366
#
# Run 8837758 on task 49
# 2019-09-02 17:01:58.034126
# One or more runs of this setup were already performed on the task.
# Run 9202890 on task 49
# 2019-09-02 17:02:00.788636
# Publish openml run...
# View run online: https://www.openml.org/r/10398019
# Setup 8235961
# Flow 16366
#
# Run 5944185 on task 49
# 2019-09-02 17:02:06.936911
# Publish openml run...
# View run online: https://www.openml.org/r/10398020
# Setup 8235967
# Flow 16366
#
# Run 9203002 on task 49
# 2019-09-02 17:02:13.493027
# Publish openml run...
# View run online: https://www.openml.org/r/10398021
# Setup 8235963
# Flow 16366
#
# Run 8810361 on task 49
# 2019-09-02 17:02:20.140072
# Publish openml run...
# View run online: https://www.openml.org/r/10398022
# Setup 8235780
# Flow 16366
#
# Run 8702403 on task 49
# 2019-09-02 17:02:25.302400
# Publish openml run...
# View run online: https://www.openml.org/r/10398023
# Setup 8235954
# Flow 16366
#
# Run 8848182 on task 49
# 2019-09-02 17:02:32.125403
# Publish openml run...
# View run online: https://www.openml.org/r/10398024
# Setup 8235837
# Flow 16366
#
# Run 6065449 on task 49
# 2019-09-02 17:02:39.503667
# Publish openml run...
# View run online: https://www.openml.org/r/10398025
# Setup 8235871
# Flow 16366
#
# Run 9201854 on task 49
# 2019-09-02 17:02:45.649644
# One or more runs of this setup were already performed on the task.
# Run 8825576 on task 49
# 2019-09-02 17:02:49.008039
# One or more runs of this setup were already performed on the task.
# Run 5361261 on task 49
# 2019-09-02 17:02:51.801873
# Publish openml run...
# View run online: https://www.openml.org/r/10398026
# Setup 8235958
# Flow 16366
#
# Run 8820977 on task 49
# 2019-09-02 17:03:03.044510
# Publish openml run...
# View run online: https://www.openml.org/r/10398027
# Setup 8235855
# Flow 16366
#
# Run 9011655 on task 49
# 2019-09-02 17:03:09.839972
# One or more runs of this setup were already performed on the task.
# Run 9202452 on task 49
# 2019-09-02 17:03:12.102081
# One or more runs of this setup were already performed on the task.
# Run 8818452 on task 49
# 2019-09-02 17:03:14.533445
# Publish openml run...
# View run online: https://www.openml.org/r/10398028
# Setup 8235863
# Flow 16366
#
# Run 9200460 on task 49
# 2019-09-02 17:03:21.775853
# name 'auto' is not defined
# Run 9061039 on task 49
# 2019-09-02 17:03:21.807587
# Publish openml run...
# View run online: https://www.openml.org/r/10398029
# Setup 8235848
# Flow 16366
#
# Run 10321344 on task 49
# 2019-09-02 17:03:29.881110
# One or more runs of this setup were already performed on the task.
# Run 6144195 on task 49
# 2019-09-02 17:03:33.565842
# One or more runs of this setup were already performed on the task.
# Run 8826313 on task 49
# 2019-09-02 17:03:36.403042
# Publish openml run...
# View run online: https://www.openml.org/r/10398030
# Setup 8235805
# Flow 16366
#
# Run 6057703 on task 49
# 2019-09-02 17:03:43.332893
# One or more runs of this setup were already performed on the task.
# Run 6050548 on task 49
# 2019-09-02 17:03:45.543215
# Publish openml run...
# View run online: https://www.openml.org/r/10398031
# Setup 8235917
# Flow 16366
#
# Run 8989800 on task 49
# 2019-09-02 17:03:51.085360
# One or more runs of this setup were already performed on the task.
# Run 8977988 on task 49
# 2019-09-02 17:03:53.390808
# One or more runs of this setup were already performed on the task.
# Run 9201845 on task 49
# 2019-09-02 17:03:56.160512
# One or more runs of this setup were already performed on the task.
# Run 6157634 on task 49
# 2019-09-02 17:03:58.793291
# Publish openml run...
# View run online: https://www.openml.org/r/10398032
# Setup 8235797
# Flow 16366
#
# Run 9202539 on task 49
# 2019-09-02 17:04:04.787262
# Publish openml run...
# View run online: https://www.openml.org/r/10398033
# Setup 8235809
# Flow 16366
#
# Run 6055326 on task 49
# 2019-09-02 17:04:10.739304
# Publish openml run...
# View run online: https://www.openml.org/r/10398034
# Setup 8235880
# Flow 16366
#
# Run 6053156 on task 49
# 2019-09-02 17:04:17.870239
# Publish openml run...
# View run online: https://www.openml.org/r/10398035
# Setup 8235689
# Flow 16366
#
# Run 5942023 on task 49
# 2019-09-02 17:04:24.368480
# Publish openml run...
# View run online: https://www.openml.org/r/10398036
# Setup 8235762
# Flow 16366
#
# Run 6055588 on task 49
# 2019-09-02 17:04:30.389322
# Publish openml run...
# View run online: https://www.openml.org/r/10398037
# Setup 8235927
# Flow 16366
#
# Run 9202483 on task 49
# 2019-09-02 17:05:01.430777
# Publish openml run...
# View run online: https://www.openml.org/r/10398038
# Setup 8235711
# Flow 16366
#
# Run 7451303 on task 49
# 2019-09-02 17:05:09.807810
# Publish openml run...
# View run online: https://www.openml.org/r/10398039
# Setup 8235883
# Flow 16366
#
# Run 8983669 on task 49
# 2019-09-02 17:05:15.867436
# One or more runs of this setup were already performed on the task.
# Run 5929020 on task 49
# 2019-09-02 17:05:20.164311
# Publish openml run...
# View run online: https://www.openml.org/r/10398040
# Setup 8235682
# Flow 16366
#
# Run 6055928 on task 49
# 2019-09-02 17:05:26.003966
# Publish openml run...
# View run online: https://www.openml.org/r/10398041
# Setup 8235920
# Flow 16366
#
# Run 6001882 on task 49
# 2019-09-02 17:05:34.301336
# Publish openml run...
# View run online: https://www.openml.org/r/10398042
# Setup 8235949
# Flow 16366
#
# Run 9202083 on task 49
# 2019-09-02 17:05:39.827653
# Publish openml run...
# View run online: https://www.openml.org/r/10398043
# Setup 8235670
# Flow 16366
#
# Run 2088416 on task 49
# 2019-09-02 17:05:45.196216
# Publish openml run...
# View run online: https://www.openml.org/r/10398044
# Setup 8235876
# Flow 16366
#
# Run 8734118 on task 49
# 2019-09-02 17:05:51.195464
# Publish openml run...
# View run online: https://www.openml.org/r/10398045
# Setup 8235916
# Flow 16366
#
# Run 9201842 on task 49
# 2019-09-02 17:05:57.032236
# Publish openml run...
# View run online: https://www.openml.org/r/10398046
# Setup 8235721
# Flow 16366
#
# Run 9202044 on task 49
# 2019-09-02 17:06:02.565445
# Publish openml run...
# View run online: https://www.openml.org/r/10398047
# Setup 8235814
# Flow 16366
#
# Run 8980523 on task 49
# 2019-09-02 17:06:10.448672
# One or more runs of this setup were already performed on the task.
# Run 5235076 on task 49
# 2019-09-02 17:06:13.618298
# One or more runs of this setup were already performed on the task.
# Run 6058985 on task 49
# 2019-09-02 17:06:16.382741
# One or more runs of this setup were already performed on the task.
# Run 6140557 on task 49
# 2019-09-02 17:06:18.965144
# Publish openml run...
# View run online: https://www.openml.org/r/10398048
# Setup 8235912
# Flow 16366
#
# Run 6130781 on task 49
# 2019-09-02 17:06:26.541026
# Publish openml run...
# View run online: https://www.openml.org/r/10398049
# Setup 8235943
# Flow 16366
#
# Run 8698926 on task 49
# 2019-09-02 17:06:33.764551
# Publish openml run...
# View run online: https://www.openml.org/r/10398050
# Setup 8235720
# Flow 16366
#
# Run 9202092 on task 49
# 2019-09-02 17:06:40.628499
# One or more runs of this setup were already performed on the task.
# Run 7487080 on task 49
# 2019-09-02 17:06:43.415307
# Publish openml run...
# View run online: https://www.openml.org/r/10398051
# Setup 8235758
# Flow 16366
#
# Run 9202052 on task 49
# 2019-09-02 17:06:52.664682
# Publish openml run...
# View run online: https://www.openml.org/r/10398052
# Setup 8235783
# Flow 16366
#
# Run 5900352 on task 49
# 2019-09-02 17:07:01.236827
# Publish openml run...
# View run online: https://www.openml.org/r/10398053
# Setup 8235658
# Flow 16366
#
# Run 6132047 on task 49
# 2019-09-02 17:07:07.381380
# Publish openml run...
# View run online: https://www.openml.org/r/10398054
# Setup 8235900
# Flow 16366
#
# Run 6057985 on task 49
# 2019-09-02 17:07:13.695329
# Publish openml run...
# View run online: https://www.openml.org/r/10398055
# Setup 8235829
# Flow 16366
#
# Run 8810075 on task 49
# 2019-09-02 17:07:22.070790
# Publish openml run...
# View run online: https://www.openml.org/r/10398056
# Setup 8235734
# Flow 16366
#
# Run 8821242 on task 49
# 2019-09-02 17:07:29.502423
# Publish openml run...
# View run online: https://www.openml.org/r/10398057
# Setup 8235680
# Flow 16366
#
# Run 8821561 on task 49
# 2019-09-02 17:07:36.592183
# One or more runs of this setup were already performed on the task.
# Run 4697466 on task 49
# 2019-09-02 17:07:40.250532
# Publish openml run...
# View run online: https://www.openml.org/r/10398058
# Setup 8235879
# Flow 16366
#
# Run 8697887 on task 49
# 2019-09-02 17:07:45.785972
# Publish openml run...
# View run online: https://www.openml.org/r/10398059
# Setup 8235845
# Flow 16366
#
# Run 8698424 on task 49
# 2019-09-02 17:07:51.802250
# Publish openml run...
# View run online: https://www.openml.org/r/10398060
# Setup 8235982
# Flow 16366
#
# Run 8704263 on task 49
# 2019-09-02 17:07:59.897358
# Publish openml run...
# View run online: https://www.openml.org/r/10398061
# Setup 8235865
# Flow 16366
#
# Run 9202914 on task 49
# 2019-09-02 17:08:07.248329
# One or more runs of this setup were already performed on the task.
# Run 9201838 on task 49
# 2019-09-02 17:08:09.742722
# Publish openml run...
# View run online: https://www.openml.org/r/10398062
# Setup 8235660
# Flow 16366
#
# Run 6053587 on task 49
# 2019-09-02 17:08:15.759557
# Publish openml run...
# View run online: https://www.openml.org/r/10398063
# Setup 8235972
# Flow 16366
#
# Run 8698360 on task 49
# 2019-09-02 17:08:25.620393
# Publish openml run...
# View run online: https://www.openml.org/r/10398064
# Setup 8235974
# Flow 16366
#
# Run 6042858 on task 49
# 2019-09-02 17:08:31.443197
# Publish openml run...
# View run online: https://www.openml.org/r/10398065
# Setup 8235919
# Flow 16366
#
# Run 9011344 on task 49
# 2019-09-02 17:08:40.954869
# Publish openml run...
# View run online: https://www.openml.org/r/10398066
# Setup 8235859
# Flow 16366
#
# Run 5065307 on task 49
# 2019-09-02 17:08:46.437168
# Publish openml run...
# View run online: https://www.openml.org/r/10398067
# Setup 8235739
# Flow 16366
#
# Run 6052750 on task 49
# 2019-09-02 17:08:53.608930
# Publish openml run...
# View run online: https://www.openml.org/r/10398068
# Setup 8235897
# Flow 16366
#
# Run 6059212 on task 49
# 2019-09-02 17:08:59.820561
# Publish openml run...
# View run online: https://www.openml.org/r/10398069
# Setup 8235669
# Flow 16366
#
# Run 6057033 on task 49
# 2019-09-02 17:09:05.816097
# Publish openml run...
# View run online: https://www.openml.org/r/10398070
# Setup 8235932
# Flow 16366
#
# Run 2088255 on task 49
# 2019-09-02 17:09:13.342155
# Publish openml run...
# View run online: https://www.openml.org/r/10398071
# Setup 8235726
# Flow 16366
#
# Run 6154080 on task 49
# 2019-09-02 17:09:20.402189
# Publish openml run...
# View run online: https://www.openml.org/r/10398072
# Setup 8235792
# Flow 16366
#
# Run 9202546 on task 49
# 2019-09-02 17:09:27.459117
# Publish openml run...
# View run online: https://www.openml.org/r/10398073
# Setup 8235886
# Flow 16366
#
# Run 5930437 on task 49
# 2019-09-02 17:09:33.576903
# Publish openml run...
# View run online: https://www.openml.org/r/10398074
# Setup 8235984
# Flow 16366
#
# Run 6066012 on task 49
# 2019-09-02 17:09:39.142525
# Publish openml run...
# View run online: https://www.openml.org/r/10398075
# Setup 8235914
# Flow 16366
#
# Run 6060896 on task 49
# 2019-09-02 17:09:56.817411
# Publish openml run...
# View run online: https://www.openml.org/r/10398076
# Setup 8235763
# Flow 16366
#
# Run 9202096 on task 49
# 2019-09-02 17:10:04.430519
# Publish openml run...
# View run online: https://www.openml.org/r/10398077
# Setup 8235980
# Flow 16366
#
# Run 8841024 on task 49
# 2019-09-02 17:10:11.397755
# One or more runs of this setup were already performed on the task.
# Run 8809028 on task 49
# 2019-09-02 17:10:13.862168
# Publish openml run...
# View run online: https://www.openml.org/r/10398078
# Setup 8235956
# Flow 16366
#
# Run 2088122 on task 49
# 2019-09-02 17:10:21.231035
# Publish openml run...
# View run online: https://www.openml.org/r/10398079
# Setup 8235867
# Flow 16366
#
# Run 8702716 on task 49
# 2019-09-02 17:10:27.345524
# Publish openml run...
# View run online: https://www.openml.org/r/10398080
# Setup 8235904
# Flow 16366
#
# Run 6032818 on task 49
# 2019-09-02 17:10:34.697933
# Publish openml run...
# View run online: https://www.openml.org/r/10398081
# Setup 8235767
# Flow 16366
#
# Run 9202222 on task 49
# 2019-09-02 17:10:41.508642
# One or more runs of this setup were already performed on the task.
# Run 8818680 on task 49
# 2019-09-02 17:10:44.095549
# Publish openml run...
# View run online: https://www.openml.org/r/10398082
# Setup 8235971
# Flow 16366
#
# Run 5840098 on task 49
# 2019-09-02 17:10:50.720346
# Publish openml run...
# View run online: https://www.openml.org/r/10398083
# Setup 8235962
# Flow 16366
#
# Run 5351969 on task 49
# 2019-09-02 17:10:59.601071
# Publish openml run...
# View run online: https://www.openml.org/r/10398084
# Setup 8235868
# Flow 16366
#
# Run 9202394 on task 49
# 2019-09-02 17:11:06.045697
# Publish openml run...
# View run online: https://www.openml.org/r/10398085
# Setup 8235699
# Flow 16366
#
# Run 8705233 on task 49
# 2019-09-02 17:11:12.865164
# One or more runs of this setup were already performed on the task.
# Run 6176713 on task 49
# 2019-09-02 17:11:15.899924
# Publish openml run...
# View run online: https://www.openml.org/r/10398086
# Setup 8235882
# Flow 16366
#
# Run 8699932 on task 49
# 2019-09-02 17:11:22.163142
# Publish openml run...
# View run online: https://www.openml.org/r/10398087
# Setup 8235657
# Flow 16366
#
# Run 6045454 on task 49
# 2019-09-02 17:11:28.399866
# Publish openml run...
# View run online: https://www.openml.org/r/10398088
# Setup 8235824
# Flow 16366
#
# Run 7290550 on task 49
# 2019-09-02 17:11:35.448903
# Publish openml run...
# View run online: https://www.openml.org/r/10398089
# Setup 8235929
# Flow 16366
#
# Run 8992021 on task 49
# 2019-09-02 17:11:41.940762
# Publish openml run...
# View run online: https://www.openml.org/r/10398090
# Setup 8235953
# Flow 16366
#
# Run 8750238 on task 49
# 2019-09-02 17:11:49.373544
# Publish openml run...
# View run online: https://www.openml.org/r/10398091
# Setup 8235801
# Flow 16366
#
# Run 2080414 on task 49
# 2019-09-02 17:11:55.279753
# Publish openml run...
# View run online: https://www.openml.org/r/10398092
# Setup 8235751
# Flow 16366
#
# Run 9202187 on task 49
# 2019-09-02 17:12:03.076412
# One or more runs of this setup were already performed on the task.
# Run 9201923 on task 49
# 2019-09-02 17:12:05.830527
# Publish openml run...
# View run online: https://www.openml.org/r/10398093
# Setup 8235807
# Flow 16366
#
# Run 8829560 on task 49
# 2019-09-02 17:12:12.758334
# Publish openml run...
# View run online: https://www.openml.org/r/10398094
# Setup 8235911
# Flow 16366
#
# Run 6060326 on task 49
# 2019-09-02 17:12:18.774150
# Publish openml run...
# View run online: https://www.openml.org/r/10398095
# Setup 8235738
# Flow 16366
#
# Run 5954854 on task 49
# 2019-09-02 17:12:28.104433
# Publish openml run...
# View run online: https://www.openml.org/r/10398096
# Setup 8235667
# Flow 16366
#
# Run 8826476 on task 49
# 2019-09-02 17:12:33.662931
# Publish openml run...
# View run online: https://www.openml.org/r/10398097
# Setup 8235741
# Flow 16366
#
# Run 6061030 on task 49
# 2019-09-02 17:12:39.440556
# Publish openml run...
# View run online: https://www.openml.org/r/10398098
# Setup 8235831
# Flow 16366
#
# Run 9203009 on task 49
# 2019-09-02 17:12:44.998812
# Publish openml run...
# View run online: https://www.openml.org/r/10398099
# Setup 8235744
# Flow 16366
#
# Run 4697546 on task 49
# 2019-09-02 17:12:52.060419
# Publish openml run...
# View run online: https://www.openml.org/r/10398100
# Setup 8235881
# Flow 16366
#
# Run 8699217 on task 49
# 2019-09-02 17:12:57.270269
# Publish openml run...
# View run online: https://www.openml.org/r/10398101
# Setup 8235740
# Flow 16366
#
# Run 6177085 on task 49
# 2019-09-02 17:13:04.785613
# Publish openml run...
# View run online: https://www.openml.org/r/10398102
# Setup 8235935
# Flow 16366
#
# Run 9202389 on task 49
# 2019-09-02 17:13:13.119702
# Publish openml run...
# View run online: https://www.openml.org/r/10398103
# Setup 8235842
# Flow 16366
#
# Run 8827375 on task 49
# 2019-09-02 17:13:19.097305
# Publish openml run...
# View run online: https://www.openml.org/r/10398104
# Setup 8235921
# Flow 16366
#
# Run 8808261 on task 49
# 2019-09-02 17:13:25.099051
# Publish openml run...
# View run online: https://www.openml.org/r/10398105
# Setup 8235742
# Flow 16366
#
# Run 9202283 on task 49
# 2019-09-02 17:13:31.077259
# Publish openml run...
# View run online: https://www.openml.org/r/10398106
# Setup 8235964
# Flow 16366
#
# Run 6146552 on task 49
# 2019-09-02 17:13:37.295005
# Publish openml run...
# View run online: https://www.openml.org/r/10398107
# Setup 8235835
# Flow 16366
#
# Run 10321757 on task 49
# 2019-09-02 17:13:43.531601
# One or more runs of this setup were already performed on the task.
# Run 8817160 on task 49
# 2019-09-02 17:13:46.580979
# Publish openml run...
# View run online: https://www.openml.org/r/10398108
# Setup 8235811
# Flow 16366
#
# Run 8735833 on task 49
# 2019-09-02 17:13:52.926269
# Publish openml run...
# View run online: https://www.openml.org/r/10398109
# Setup 8235653
# Flow 16366
#
# Run 8745470 on task 49
# 2019-09-02 17:14:00.228863
# Publish openml run...
# View run online: https://www.openml.org/r/10398110
# Setup 8235761
# Flow 16366
#
# Run 9202373 on task 49
# 2019-09-02 17:14:06.408905
# Publish openml run...
# View run online: https://www.openml.org/r/10398111
# Setup 8235843
# Flow 16366
#
# Run 6146968 on task 49
# 2019-09-02 17:14:14.393324
# Publish openml run...
# View run online: https://www.openml.org/r/10398112
# Setup 8235976
# Flow 16366
#
# Run 5919852 on task 49
# 2019-09-02 17:14:20.848100
# Publish openml run...
# View run online: https://www.openml.org/r/10398113
# Setup 8235872
# Flow 16366
#
# Run 8805550 on task 49
# 2019-09-02 17:14:28.372087
# Publish openml run...
# View run online: https://www.openml.org/r/10398114
# Setup 8235930
# Flow 16366
#
# Run 9202337 on task 49
# 2019-09-02 17:14:34.053194
# Publish openml run...
# View run online: https://www.openml.org/r/10398115
# Setup 8235666
# Flow 16366
#
# Run 9201934 on task 49
# 2019-09-02 17:14:40.484932
# One or more runs of this setup were already performed on the task.
# Run 5976309 on task 49
# 2019-09-02 17:14:43.391520
# Publish openml run...
# View run online: https://www.openml.org/r/10398116
# Setup 8235892
# Flow 16366
#
# Run 8808244 on task 49
# 2019-09-02 17:14:50.220883
# Publish openml run...
# View run online: https://www.openml.org/r/10398117
# Setup 8235899
# Flow 16366
#
# Run 8991482 on task 49
# 2019-09-02 17:14:56.991937
# One or more runs of this setup were already performed on the task.
# Run 6054213 on task 49
# 2019-09-02 17:15:00.161784
# Publish openml run...
# View run online: https://www.openml.org/r/10398118
# Setup 8235661
# Flow 16366
#
# Run 4797668 on task 49
# 2019-09-02 17:15:10.405929
# Publish openml run...
# View run online: https://www.openml.org/r/10398119
# Setup 8235874
# Flow 16366
#
# Run 8804593 on task 49
# 2019-09-02 17:15:16.446826
# Publish openml run...
# View run online: https://www.openml.org/r/10398120
# Setup 8235808
# Flow 16366
#
# Run 8808340 on task 49
# 2019-09-02 17:15:22.286696
# One or more runs of this setup were already performed on the task.
# Run 5803533 on task 49
# 2019-09-02 17:15:25.355812
# Publish openml run...
# View run online: https://www.openml.org/r/10398121
# Setup 8235937
# Flow 16366
#
# Run 8980130 on task 49
# 2019-09-02 17:15:32.285910
# Publish openml run...
# View run online: https://www.openml.org/r/10398122
# Setup 8235725
# Flow 16366
#
# Run 8815968 on task 49
# 2019-09-02 17:15:38.874647
# Publish openml run...
# View run online: https://www.openml.org/r/10398123
# Setup 8235857
# Flow 16366
#
# Run 10321505 on task 49
# 2019-09-02 17:15:44.353269
# Publish openml run...
# View run online: https://www.openml.org/r/10398124
# Setup 8235922
# Flow 16366
#
# Run 6042216 on task 49
# 2019-09-02 17:15:51.162027
# ...
# 2019-09-02 17:27:54.609265
# One or more runs of this setup were already performed on the task.
# Run 8750135 on task 49
# 2019-09-02 17:27:58.302794
# One or more runs of this setup were already performed on the task.
# Run 9203002 on task 49
# 2019-09-02 17:28:01.676370
# One or more runs of this setup were already performed on the task.
# Run 8808244 on task 49
# 2019-09-02 17:28:05.361082
# One or more runs of this setup were already performed on the task.
# Run 8848691 on task 49
# 2019-09-02 17:28:08.432719
# One or more runs of this setup were already performed on the task.
# Run 8816289 on task 49
# 2019-09-02 17:28:11.811280
# One or more runs of this setup were already performed on the task.
# Run 4750755 on task 49
# 2019-09-02 17:28:15.499395
# One or more runs of this setup were already performed on the task.
# Run 6176713 on task 49
# 2019-09-02 17:28:19.184432
# One or more runs of this setup were already performed on the task.
# Run 5970635 on task 49
# 2019-09-02 17:28:21.895207
# One or more runs of this setup were already performed on the task.
# Run 8980523 on task 49
# 2019-09-02 17:28:25.635106
# One or more runs of this setup were already performed on the task.
# Run 9202708 on task 49
# 2019-09-02 17:28:28.706732
# One or more runs of this setup were already performed on the task.
# Run 8697166 on task 49
# 2019-09-02 17:28:31.480415
# One or more runs of this setup were already performed on the task.
# Run 6056722 on task 49
# 2019-09-02 17:28:34.389819
# One or more runs of this setup were already performed on the task.
# Run 8826085 on task 49
# 2019-09-02 17:28:37.000714
# One or more runs of this setup were already performed on the task.
# Run 8830529 on task 49
# 2019-09-02 17:28:40.379627
# One or more runs of this setup were already performed on the task.
# Run 8810075 on task 49
# 2019-09-02 17:28:43.450681
# One or more runs of this setup were already performed on the task.
# Run 8813676 on task 49
# 2019-09-02 17:28:46.191781
# One or more runs of this setup were already performed on the task.
# Run 8708418 on task 49
# 2019-09-02 17:28:48.983499
# One or more runs of this setup were already performed on the task.
# Run 8985244 on task 49
# 2019-09-02 17:28:51.441060
# One or more runs of this setup were already performed on the task.
# Run 8827790 on task 49
# 2019-09-02 17:28:54.138230
# One or more runs of this setup were already performed on the task.
# Run 6035362 on task 49
# 2019-09-02 17:28:57.275047
# One or more runs of this setup were already performed on the task.
# Run 8702403 on task 49
# 2019-09-02 17:28:59.733875
# One or more runs of this setup were already performed on the task.
# Run 6066012 on task 49
# 2019-09-02 17:29:02.495491
# One or more runs of this setup were already performed on the task.
# Run 8700114 on task 49
# 2019-09-02 17:29:06.491104
# One or more runs of this setup were already performed on the task.
# Run 8727711 on task 49
# 2019-09-02 17:29:10.487662
# One or more runs of this setup were already performed on the task.
# Run 9202960 on task 49
# 2019-09-02 17:29:12.944633
# One or more runs of this setup were already performed on the task.
# Run 10321344 on task 49
# 2019-09-02 17:29:15.092247
# One or more runs of this setup were already performed on the task.
# Run 5954854 on task 49
# 2019-09-02 17:29:17.860171
# One or more runs of this setup were already performed on the task.
# Run 9202942 on task 49
# 2019-09-02 17:29:21.554414
# One or more runs of this setup were already performed on the task.
# Run 8808261 on task 49
# 2019-09-02 17:29:24.316131
# One or more runs of this setup were already performed on the task.
# Run 5192367 on task 49
# 2019-09-02 17:29:26.718926
# One or more runs of this setup were already performed on the task.
# Run 8735833 on task 49
# 2019-09-02 17:29:29.463335
# One or more runs of this setup were already performed on the task.
# Run 9201934 on task 49
# 2019-09-02 17:29:31.990184
# One or more runs of this setup were already performed on the task.
# Run 8826601 on task 49
# 2019-09-02 17:29:33.962214
# One or more runs of this setup were already performed on the task.
# Run 6057703 on task 49
# 2019-09-02 17:29:37.518814
# One or more runs of this setup were already performed on the task.
# Run 8840661 on task 49
# 2019-09-02 17:29:40.061351
# One or more runs of this setup were already performed on the task.
# Run 9202177 on task 49
# 2019-09-02 17:29:42.295314
# One or more runs of this setup were already performed on the task.
# Run 6042858 on task 49
# 2019-09-02 17:29:44.891057
# One or more runs of this setup were already performed on the task.
# Run 6140557 on task 49
# 2019-09-02 17:29:48.233334
# One or more runs of this setup were already performed on the task.
# Run 6061030 on task 49
# 2019-09-02 17:29:51.036876
# One or more runs of this setup were already performed on the task.
# Run 6057033 on task 49
# 2019-09-02 17:29:54.107295
# One or more runs of this setup were already performed on the task.
# Run 8818680 on task 49
# 2019-09-02 17:29:57.321018
# One or more runs of this setup were already performed on the task.
# Run 6032818 on task 49
# 2019-09-02 17:29:59.621301
# One or more runs of this setup were already performed on the task.
# Run 8702001 on task 49
# 2019-09-02 17:30:03.629622
# One or more runs of this setup were already performed on the task.
# Run 6054637 on task 49
# 2019-09-02 17:30:06.523312
# One or more runs of this setup were already performed on the task.
# Run 8696108 on task 49
# 2019-09-02 17:30:09.618900
# One or more runs of this setup were already performed on the task.
# Run 6799683 on task 49
# 2019-09-02 17:30:12.998339
# One or more runs of this setup were already performed on the task.
# Run 8821561 on task 49
# 2019-09-02 17:30:15.926048
# One or more runs of this setup were already performed on the task.
# Run 9202994 on task 49
# 2019-09-02 17:30:18.376300
# One or more runs of this setup were already performed on the task.
# Run 7321131 on task 49
# 2019-09-02 17:30:21.734503
# One or more runs of this setup were already performed on the task.
# Run 6060896 on task 49
# 2019-09-02 17:30:24.825010
# One or more runs of this setup were already performed on the task.
# Run 5929020 on task 49
# 2019-09-02 17:30:28.210345
# One or more runs of this setup were already performed on the task.
# Run 6001882 on task 49
# 2019-09-02 17:30:30.865283
# One or more runs of this setup were already performed on the task.
# Run 9202914 on task 49
# 2019-09-02 17:30:33.737658
# One or more runs of this setup were already performed on the task.
# Run 10321505 on task 49
# 2019-09-02 17:30:36.823173
# One or more runs of this setup were already performed on the task.
# Run 9201804 on task 49
# 2019-09-02 17:30:40.496583
# One or more runs of this setup were already performed on the task.
# Run 9202634 on task 49
# 2019-09-02 17:30:44.489722
# One or more runs of this setup were already performed on the task.
# Run 8818452 on task 49
# 2019-09-02 17:30:47.560579
# One or more runs of this setup were already performed on the task.
# Run 9201845 on task 49
# 2019-09-02 17:30:50.631356
# One or more runs of this setup were already performed on the task.
# Run 6063709 on task 49
# 2019-09-02 17:30:53.961580
# One or more runs of this setup were already performed on the task.
# Run 6130768 on task 49
# 2019-09-02 17:30:57.082558
# One or more runs of this setup were already performed on the task.
# Run 8992021 on task 49
# 2019-09-02 17:30:59.796122
# One or more runs of this setup were already performed on the task.
# Run 9202222 on task 49
# 2019-09-02 17:31:02.516143
# One or more runs of this setup were already performed on the task.
# Run 8698113 on task 49
# 2019-09-02 17:31:05.686332
# One or more runs of this setup were already performed on the task.
# Run 4569642 on task 49
# 2019-09-02 17:31:09.987910
# One or more runs of this setup were already performed on the task.
# Run 8750238 on task 49
# 2019-09-02 17:31:12.800868
# One or more runs of this setup were already performed on the task.
# Run 8822102 on task 49
# 2019-09-02 17:31:15.824441
# One or more runs of this setup were already performed on the task.
# Run 5958221 on task 49
# 2019-09-02 17:31:18.587383
# One or more runs of this setup were already performed on the task.
# Run 6055928 on task 49
# 2019-09-02 17:31:21.290002
# One or more runs of this setup were already performed on the task.
# Run 6065128 on task 49
# 2019-09-02 17:31:24.125117
# One or more runs of this setup were already performed on the task.
# Run 5900352 on task 49
# 2019-09-02 17:31:27.640571
# One or more runs of this setup were already performed on the task.
# Run 9202979 on task 49
# 2019-09-02 17:31:31.181015
# One or more runs of this setup were already performed on the task.
# Run 8829560 on task 49
# 2019-09-02 17:31:34.174197
# One or more runs of this setup were already performed on the task.
# Run 7505447 on task 49
# 2019-09-02 17:31:37.018992
# One or more runs of this setup were already performed on the task.
# Run 8698424 on task 49
# 2019-09-02 17:31:40.402409
# One or more runs of this setup were already performed on the task.
# Run 6045896 on task 49
# 2019-09-02 17:31:42.856128
# One or more runs of this setup were already performed on the task.
# Run 8841024 on task 49
# 2019-09-02 17:31:46.237416
# One or more runs of this setup were already performed on the task.
# Run 8739373 on task 49
# 2019-09-02 17:31:48.624888
# One or more runs of this setup were already performed on the task.
# Run 8977988 on task 49
# 2019-09-02 17:31:51.905788
# One or more runs of this setup were already performed on the task.
# Run 8826438 on task 49
# 2019-09-02 17:31:55.280990
# One or more runs of this setup were already performed on the task.
# Run 8827829 on task 49
# 2019-09-02 17:31:57.913569
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-a1f1a32da379> in <module>
#      49
#      50             # run best model on the task
# ---> 51             run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=True)
#      52
#      53             # print feedbackack
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in run_model_on_task(model, task, avoid_duplicate_runs, flow_tags, seed, add_local_measures, upload_flow, return_flow)
#     104         seed=seed,
#     105         add_local_measures=add_local_measures,
# --> 106         upload_flow=upload_flow,
#     107     )
#     108     if return_flow:
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in run_flow_on_task(flow, task, avoid_duplicate_runs, flow_tags, seed, add_local_measures, upload_flow)
#     197             if avoid_duplicate_runs:
#     198                 flow_from_server.model = flow.model
# --> 199                 setup_id = setup_exists(flow_from_server)
#     200                 ids = run_exists(task.task_id, setup_id)
#     201                 if ids:
#
# /miniconda3/lib/python3.7/site-packages/openml/setups/functions.py in setup_exists(flow)
#      50     result = openml._api_calls._perform_api_call('/setup/exists/',
#      51                                                  'post',
# ---> 52                                                  file_elements=file_elements)
#      53     result_dict = xmltodict.parse(result)
#      54     setup_id = int(result_dict['oml:setup_exists']['oml:id'])
#
# /miniconda3/lib/python3.7/site-packages/openml/_api_calls.py in _perform_api_call(call, request_method, data, file_elements)
#      48             raise ValueError('request method must be post when file elements '
#      49                              'are present')
# ---> 50         return _read_url_files(url, data=data, file_elements=file_elements)
#      51     return _read_url(url, request_method, data)
#      52
#
# /miniconda3/lib/python3.7/site-packages/openml/_api_calls.py in _read_url_files(url, data, file_elements)
#      78         url=url,
#      79         data=data,
# ---> 80         files=file_elements,
#      81     )
#      82     if response.status_code != 200:
#
# /miniconda3/lib/python3.7/site-packages/openml/_api_calls.py in send_request(request_method, url, data, files)
#     121                     response = session.delete(url, params=data)
#     122                 elif request_method == 'post':
# --> 123                     response = session.post(url, data=data, files=files)
#     124                 else:
#     125                     raise NotImplementedError()
#
# /miniconda3/lib/python3.7/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     579         """
#     580
# --> 581         return self.request('POST', url, data=data, json=json, **kwargs)
#     582
#     583     def put(self, url, data=None, **kwargs):
#
# /miniconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /miniconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /miniconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /miniconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# /miniconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# /miniconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# /miniconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:

# %% [markdown]
# ## Trying to make callables work

# %%
def cont(X):
    return X.dtypes != 'category'

def cat(X):
    return X.dtypes == 'category'

# %%
# get relevant info from dataset object
X, y, _, _ = data.get_data(target=data.default_target_attribute)

type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
# get task
task = openml.tasks.get_task(23)

# get dataset object 
data = openml.datasets.get_dataset(task.dataset_id)

# get relevant info from dataset object
X, y, categorical_indicator, attribute_names = data.get_data(target=data.default_target_attribute)

cat = categorical_indicator
num = [not k for k in categorical_indicator]

def cat_call(A):
    return A.dtypes == 'category'

def num_call(A):
    return A.dtypes != 'category'

# make columntransformer
#numeric_transformer = make_pipeline(StandardScaler())
#categorical_transformer = make_pipeline(OneHotEncoder(handle_unknown='ignore'))
#preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, cont), 
#                                              ('cat', categorical_transformer, cat)])

preprocessor = make_column_transformer((StandardScaler(), cat_call),
                                      (OneHotEncoder(categories = 'auto'), num_call))

# make pipeline
clf = SVC(gamma = 'scale', random_state=3)
pipe = make_pipeline(preprocessor, clf)

# run task
run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=False)
run.publish()

# check setup 
openml.runs.get_run(run.run_id).setup_id
# Out:
# /miniconda3/lib/python3.7/site-packages/openml/datasets/dataset.py:448: UserWarning: Cannot convert non-sparse data to 'dataframe'. Returning input data.
#   warn("Cannot convert {} to '{}'. Returning input data.".format(data_type, array_format))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /miniconda3/lib/python3.7/site-packages/openml/extensions/sklearn/extension.py in _run_model_on_fold(self, model, task, X_train, rep_no, fold_no, y_train, X_test)
#    1357             if isinstance(task, OpenMLSupervisedTask):
# -> 1358                 model_copy.fit(X_train, y_train)
#    1359             elif isinstance(task, OpenMLClusteringTask):
#
# /miniconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#
# /miniconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#
# /miniconda3/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#
# /miniconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     464         self._validate_transformers()
# --> 465         self._validate_column_callables(X)
#     466         self._validate_remainder(X)
#
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in _validate_column_callables(self, X)
#     285             if callable(column):
# --> 286                 column = column(X)
#     287             columns.append(column)
#
# <ipython-input-132-3279d97a1b0c> in cat_call(A)
#      13 def cat_call(A):
# ---> 14     return A.dtypes == 'category'
#      15
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dtypes'
#
# During handling of the above exception, another exception occurred:
#
# PyOpenMLError                             Traceback (most recent call last)
# <ipython-input-132-3279d97a1b0c> in <module>
#      31
#      32 # run task
# ---> 33 run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=False)
#      34 run.publish()
#      35
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in run_model_on_task(model, task, avoid_duplicate_runs, flow_tags, seed, add_local_measures, upload_flow, return_flow)
#     104         seed=seed,
#     105         add_local_measures=add_local_measures,
# --> 106         upload_flow=upload_flow,
#     107     )
#     108     if return_flow:
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in run_flow_on_task(flow, task, avoid_duplicate_runs, flow_tags, seed, add_local_measures, upload_flow)
#     220         task=task,
#     221         extension=flow.extension,
# --> 222         add_local_measures=add_local_measures,
#     223     )
#     224
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in _run_task_get_arffcontent(flow, model, task, extension, add_local_measures)
#     444             rep_no=rep_no,
#     445             fold_no=fold_no,
# --> 446             X_test=test_x,
#     447         )
#     448         if trace is not None:
#
# /miniconda3/lib/python3.7/site-packages/openml/extensions/sklearn/extension.py in _run_model_on_fold(self, model, task, X_train, rep_no, fold_no, y_train, X_test)
#    1370         except AttributeError as e:
#    1371             # typically happens when training a regressor on classification task
# -> 1372             raise PyOpenMLError(str(e))
#    1373
#    1374         if isinstance(task, (OpenMLClassificationTask, OpenMLLearningCurveTask)):
#
# PyOpenMLError: 'numpy.ndarray' object has no attribute 'dtypes'

# %%
# %debug
# Out:
# > /miniconda3/lib/python3.7/site-packages/openml/extensions/sklearn/extension.py(1372)_run_model_on_fold()
#    1370         except AttributeError as e:
#    1371             # typically happens when training a regressor on classification task
# -> 1372             raise PyOpenMLError(str(e))
#    1373
#    1374         if isinstance(task, (OpenMLClassificationTask, OpenMLLearningCurveTask)):
#
# ipdb> up
# > /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py(446)_run_task_get_arffcontent()
#     444             rep_no=rep_no,
#     445             fold_no=fold_no,
# --> 446             X_test=test_x,
#     447         )
#     448         if trace is not None:
#
# ipdb> up
# > /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py(222)run_flow_on_task()
#     220         task=task,
#     221         extension=flow.extension,
# --> 222         add_local_measures=add_local_measures,
#     223     )
#     224
#
# ipdb> up
# > /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py(106)run_model_on_task()
#     104         seed=seed,
#     105         add_local_measures=add_local_measures,
# --> 106         upload_flow=upload_flow,
#     107     )
#     108     if return_flow:
#
# ipdb> list
#     101         flow=flow,
#     102         avoid_duplicate_runs=avoid_duplicate_runs,
#     103         flow_tags=flow_tags,
#     104         seed=seed,
#     105         add_local_measures=add_local_measures,
# --> 106         upload_flow=upload_flow,
#     107     )
#     108     if return_flow:
#     109         return run, flow
#     110     return run
#     111
#
# ipdb> list 100
#      95         raise TypeError(extension)
#      96
#      97     flow = extension.model_to_flow(model)
#      98
#      99     run = run_flow_on_task(
#     100         task=task,
#     101         flow=flow,
#     102         avoid_duplicate_runs=avoid_duplicate_runs,
#     103         flow_tags=flow_tags,
#     104         seed=seed,
#     105         add_local_measures=add_local_measures,
#
# ipdb> down
# > /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py(222)run_flow_on_task()
#     220         task=task,
#     221         extension=flow.extension,
# --> 222         add_local_measures=add_local_measures,
#     223     )
#     224
#
# ipdb> down
# > /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py(446)_run_task_get_arffcontent()
#     444             rep_no=rep_no,
#     445             fold_no=fold_no,
# --> 446             X_test=test_x,
#     447         )
#     448         if trace is not None:
#
# ipdb> p test_X
# *** NameError: name 'test_X' is not defined
# ipdb> p test_x
# array([[37.,  2.,  3., ...,  1.,  3.,  0.],
#        [41.,  2.,  1., ...,  1.,  2.,  0.],
#        [45.,  1.,  2., ...,  1.,  2.,  0.],
#        ...,
#        [23.,  3.,  3., ...,  2.,  2.,  0.],
#        [25.,  2.,  0., ...,  2.,  3.,  0.],
#        [48.,  3.,  3., ...,  0.,  3.,  0.]], dtype=float32)
# ipdb> exit

# %% [markdown]
# ## Trying to write my own transformer

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class TypeSelector(BaseEstimator, TransformerMixin):
    def __init__(self, dtype):
        self.dtype = dtype
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        assert isinstance(X, pd.DataFrame)
        return X.select_dtypes(include=[self.dtype])

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import OneHotEncoder, StandardScaler

transformer = Pipeline([('features', FeatureUnion(n_jobs=1, transformer_list=[
        ('bool', Pipeline([('selector', TypeSelector('bool')),])), 
        ('num', Pipeline([('selector', TypeSelector(np.number)),('scaler', StandardScaler()),])), 
        ('cat', Pipeline([('selector', TypeSelector('category')),('encoder', OneHotEncoder(handle_unknown='ignore')),]))  
    ])),
])

# %%
# get task
task = openml.tasks.get_task(3022)

# get dataset object 
data = openml.datasets.get_dataset(task.dataset_id)

# make pipeline
clf = SVC(gamma = 'scale', random_state=3)
pipe = make_pipeline(clf)

# run task
run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=False)
run.publish()

# check setup 
openml.runs.get_run(run.run_id).setup_id
# Out:
# 8234482

# %%
# get task
task = openml.tasks.get_task(23)

# get dataset object 
data = openml.datasets.get_dataset(task.dataset_id)

# make pipeline
clf = SVC(gamma = 'scale', random_state=3)
pipe = make_pipeline(clf)

# run task
run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=False)
run.publish()

# check setup 
openml.runs.get_run(run.run_id).setup_id
# Out:
# 8234482

# %%
# get task
task = openml.tasks.get_task(3022)

# get dataset object 
data = openml.datasets.get_dataset(task.dataset_id)

# get relevant info from dataset object
X, y, _, _ = data.get_data(target=data.default_target_attribute)

# make pipeline
clf = SVC(gamma = 'scale', random_state=3)
pipe = make_pipeline(transformer, clf)

pipe.fit(X, y)
# Out:
# /miniconda3/lib/python3.7/site-packages/openml/datasets/dataset.py:448: UserWarning: Cannot convert non-sparse data to 'dataframe'. Returning input data.
#   warn("Cannot convert {} to '{}'. Returning input data.".format(data_type, array_format))
# Pipeline(memory=None,
#          steps=[('pipeline',
#                  Pipeline(memory=None,
#                           steps=[('features',
#                                   FeatureUnion(n_jobs=1,
#                                                transformer_list=[('bool',
#                                                                   Pipeline(memory=None,
#                                                                            steps=[('selector',
#                                                                                    TypeSelector(dtype='bool'))],
#                                                                            verbose=False)),
#                                                                  ('num',
#                                                                   Pipeline(memory=None,
#                                                                            steps=[('selector',
#                                                                                    TypeSelector(dtype=<class 'numpy.number'>)),
#                                                                                   ('scaler',
#                                                                                    StandardScaler(copy=True,
#                                                                                                   with_mean=Tr...
#                                                                                                  handle_unknown='ignore',
#                                                                                                  n_values=None,
#                                                                                                  sparse=True))],
#                                                                            verbose=False))],
#                                                transformer_weights=None,
#                                                verbose=False))],
#                           verbose=False)),
#                 ('svc',
#                  SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3, gamma='scale',
#                      kernel='rbf', max_iter=-1, probability=False,
#                      random_state=3, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)
