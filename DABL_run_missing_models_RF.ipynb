# %% [markdown]
# # Run missing models

# %% [markdown]
# ## Import modules

# %%
import openml
from openml import tasks, flows, runs
import sklearn
from sklearn import feature_selection
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import pprint
from collections import OrderedDict, Counter
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
import re
import random
import numpy as np
from datetime import datetime
import sys
import json
from itertools import combinations
import signal

import importlib
import utils.functions_analyze_runs
importlib.reload(utils.functions_analyze_runs)
importlib.reload(sklearn)
from utils.functions_analyze_runs import get_run_info_rf, get_run_info

# set api key
openml.config.apikey = open('.key', 'r').readline().strip('\n')

# %%
missing = pd.read_csv('rf_missing.csv').iloc[:,[1,2]]

# %%
missing
# Out:
#      setup_id  task_id
# 0     8261487     3021
# 1     8261494     3021
# 2     8261509     3021
# 3     8261514     3021
# 4     8261516     3021
# ..        ...      ...
# 940   8262202   167125
# 941   8262208   167125
# 942   8262236   167125
# 943   8262261   167125
# 944   8262277   167125
#
# [945 rows x 2 columns]

# %% [markdown]
# ## Iterate through missing runs in random order

# %%
# infinite loop
for i in [3021]:

    # get task
    task = openml.tasks.get_task(i)
    
    # get dataset object
    data = openml.datasets.get_dataset(task.dataset_id)

    # get relevant info from dataset object
    X, y, categorical_indicator, attribute_names = data.get_data(dataset_format='array',
                                                                target=data.default_target_attribute)

    # mask with feature types
    cat = categorical_indicator
    num = [not k for k in categorical_indicator]

    # create column transformers
    numeric_transformer = make_pipeline(#SimpleImputer(strategy='median'), 
                                        StandardScaler())

    categorical_transformer = make_pipeline(#SimpleImputer(strategy='most_frequent'),
                                            OneHotEncoder(handle_unknown='ignore'))

    preprocessor = ColumnTransformer(
    transformers=[
    ('num', numeric_transformer, num),
    ('cat', categorical_transformer, cat)])
    
    # loop over runs in random order
    for k in missing[missing['task_id'] == i].setup_id:
        
        print('Run', k, 'on task', i)
        print(datetime.now())
        
        try:
            # get params
            params = openml.setups.initialize_model(k).steps[2][1].get_params()

            # define classifier
            clf = RandomForestClassifier(**params)

            # pick pipeline according to feature types
            if not any(categorical_indicator):
                pipe = make_pipeline(SimpleImputer(strategy='median'), StandardScaler(), clf)
            elif all(categorical_indicator):
                pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore'), clf)
            else:
                pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), preprocessor, clf)
                
            # run best model on the task
            run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=False)

            # print feedbackack
            print('Publish openml run...')

            # push tag
            # run.push_tag('best_models')
            # publish the run
            
            run.publish()
            # print feedback
            print('View run online: https://www.openml.org/r/' + str(run.run_id))
            print('Setup', openml.runs.get_run(run.run_id).setup_id)
            print('Flow', openml.runs.get_run(run.run_id).flow_id)
            print()

        except Exception as e:
            print(e)
# Out:
# Run 8261487 on task 3021
# 2020-08-11 19:04:50.235504
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261494 on task 3021
# 2020-08-11 19:04:50.360689
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261509 on task 3021
# 2020-08-11 19:04:50.476811
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261514 on task 3021
# 2020-08-11 19:04:50.579511
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261516 on task 3021
# 2020-08-11 19:04:50.693682
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261517 on task 3021
# 2020-08-11 19:04:50.820064
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261520 on task 3021
# 2020-08-11 19:04:50.929542
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261522 on task 3021
# 2020-08-11 19:04:51.031807
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261524 on task 3021
# 2020-08-11 19:04:51.172482
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261526 on task 3021
# 2020-08-11 19:04:51.290533
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261527 on task 3021
# 2020-08-11 19:04:51.448687
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261528 on task 3021
# 2020-08-11 19:04:51.555816
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261529 on task 3021
# 2020-08-11 19:04:51.668916
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261537 on task 3021
# 2020-08-11 19:04:51.784717
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261540 on task 3021
# 2020-08-11 19:04:51.912756
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261543 on task 3021
# 2020-08-11 19:04:52.041275
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261544 on task 3021
# 2020-08-11 19:04:52.321787
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261547 on task 3021
# 2020-08-11 19:04:52.434201
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261550 on task 3021
# 2020-08-11 19:04:52.552426
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261553 on task 3021
# 2020-08-11 19:04:52.679891
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261555 on task 3021
# 2020-08-11 19:04:52.806525
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261556 on task 3021
# 2020-08-11 19:04:52.933653
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261558 on task 3021
# 2020-08-11 19:04:53.073126
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261562 on task 3021
# 2020-08-11 19:04:53.178968
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261565 on task 3021
# 2020-08-11 19:04:53.280489
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261567 on task 3021
# 2020-08-11 19:04:53.386524
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261568 on task 3021
# 2020-08-11 19:04:53.487975
# boolean index did not match indexed array along dimension 0; dimension is 28 but corresponding boolean dimension is 29
# Run 8261570 on task 3021
# 2020-08-11 19:04:53.599351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9dc4e14d6d5e> in <module>
#      50
#      51             # run best model on the task
# ---> 52             run = openml.runs.run_model_on_task(pipe, task, avoid_duplicate_runs=False)
#      53
#      54             # print feedbackack
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in run_model_on_task(model, task, avoid_duplicate_runs, flow_tags, seed, add_local_measures, upload_flow, return_flow)
#     106         seed=seed,
#     107         add_local_measures=add_local_measures,
# --> 108         upload_flow=upload_flow,
#     109     )
#     110     if return_flow:
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in run_flow_on_task(flow, task, avoid_duplicate_runs, flow_tags, seed, add_local_measures, upload_flow)
#     222         task=task,
#     223         extension=flow.extension,
# --> 224         add_local_measures=add_local_measures,
#     225     )
#     226
#
# /miniconda3/lib/python3.7/site-packages/openml/runs/functions.py in _run_task_get_arffcontent(flow, model, task, extension, add_local_measures)
#     446             rep_no=rep_no,
#     447             fold_no=fold_no,
# --> 448             X_test=test_x,
#     449         )
#     450         if trace is not None:
#
# /miniconda3/lib/python3.7/site-packages/openml/extensions/sklearn/extension.py in _run_model_on_fold(self, model, task, X_train, rep_no, fold_no, y_train, X_test)
#    1532
#    1533             if isinstance(task, OpenMLSupervisedTask):
# -> 1534                 model_copy.fit(X_train, y_train)
#    1535             elif isinstance(task, OpenMLClusteringTask):
#    1536                 model_copy.fit(X_train)
#
# /miniconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     350             This estimator
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#     354                                  self._log_message(len(self.steps) - 1)):
#
# /miniconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# /miniconda3/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# /miniconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /miniconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
# --> 556             return self.fit(X, y, **fit_params).transform(X)
#     557
#     558
#
# /miniconda3/lib/python3.7/site-packages/sklearn/impute/_base.py in fit(self, X, y)
#     266                                                self.strategy,
#     267                                                self.missing_values,
# --> 268                                                fill_value)
#     269
#     270         if self.add_indicator:
#
# /miniconda3/lib/python3.7/site-packages/sklearn/impute/_base.py in _dense_fit(self, X, strategy, missing_values, fill_value)
#     356                 row_mask = np.logical_not(row_mask).astype(np.bool)
#     357                 row = row[row_mask]
# --> 358                 most_frequent[i] = _most_frequent(row, np.nan, 0)
#     359
#     360             return most_frequent
#
# /miniconda3/lib/python3.7/site-packages/sklearn/impute/_base.py in _most_frequent(array, extra_value, n_repeat)
#      59             # has already been NaN-masked.
#      60             warnings.simplefilter("ignore", RuntimeWarning)
# ---> 61             mode = stats.mode(array)
#      62
#      63         most_frequent_value = mode[0][0]
#
# /miniconda3/lib/python3.7/site-packages/scipy/stats/stats.py in mode(a, axis, nan_policy)
#     468     a_view = np.transpose(a, in_dims[:axis] + in_dims[axis+1:] + [axis])
#     469
# --> 470     inds = np.ndindex(a_view.shape[:-1])
#     471     modes = np.empty(a_view.shape[:-1], dtype=a.dtype)
#     472     counts = np.zeros(a_view.shape[:-1], dtype=np.int)
#
# /miniconda3/lib/python3.7/site-packages/numpy/lib/index_tricks.py in __init__(self, *shape)
#     637         if len(shape) == 1 and isinstance(shape[0], tuple):
#     638             shape = shape[0]
# --> 639         x = as_strided(_nx.zeros(1), shape=shape,
#     640                        strides=_nx.zeros_like(shape))
#     641         self._it = _nx.nditer(x, flags=['multi_index', 'zerosize_ok'],
#
# KeyboardInterrupt:
